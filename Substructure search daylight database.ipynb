# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
import sqlite3

# Function to convert SMILES to Daylight fingerprints
def smiles_to_fingerprint(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        fingerprint = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=2048)
        return fingerprint.ToBitString()
    else:
        return None

# Read SMILES from CSV file
df = pd.read_csv('asinex.csv')
smiles_list = df['SMILES'].tolist()

# Connect to SQLite database (create if not exists)
conn = sqlite3.connect('fingerprint_database_1.db')
cursor = conn.cursor()

# Create table for storing fingerprints
cursor.execute('''CREATE TABLE IF NOT EXISTS fingerprints (
                    id INTEGER PRIMARY KEY,
                    smiles TEXT,
                    fingerprint TEXT)''')

# Convert SMILES to fingerprints and store in database
for smiles in smiles_list:
    fingerprint = smiles_to_fingerprint(smiles)
    if fingerprint:
        cursor.execute('INSERT INTO fingerprints (smiles, fingerprint) VALUES (?, ?)', (smiles, fingerprint))

# Commit and close the database connection
conn.commit()
conn.close()

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem, DataStructs
import sqlite3

# Function to convert SMILES to Daylight fingerprints
def smiles_to_fingerprint(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        fingerprint = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=2048)
        return fingerprint.ToBitString()
    else:
        return None

# Function to calculate Tanimoto similarity
def calculate_similarity(fp1, fp2):
    fp1 = DataStructs.CreateFromBitString(fp1)
    fp2 = DataStructs.CreateFromBitString(fp2)
    return DataStructs.FingerprintSimilarity(fp1, fp2)

# Ask for user input to search for similar SMILES and similarity threshold
search_smiles = input("Enter SMILES to search for similar molecules: ")
similarity_threshold = float(input("Enter similarity threshold (0 to 1): "))
search_fp = smiles_to_fingerprint(search_smiles)

if search_fp:
    # Connect to the database to perform the similarity search
    conn = sqlite3.connect('fingerprint_database.db')
    cursor = conn.cursor()
    cursor.execute('SELECT smiles, fingerprint FROM fingerprints')
    results = cursor.fetchall()
    
    similar_molecules = []
    for row in results:
        smiles, fingerprint = row
        similarity = calculate_similarity(search_fp, fingerprint)
        if similarity >= similarity_threshold:
            similar_molecules.append((smiles, similarity))
    
    # Sort by similarity and print results
    similar_molecules.sort(key=lambda x: x[1], reverse=True)
    print(f"Similar molecules to {search_smiles} with a similarity threshold of {similarity_threshold}:")
    for smiles, similarity in similar_molecules:
        print(f"SMILES: {smiles}, Similarity: {similarity:.2f}")
    
    # Output the results to a CSV file
    df_results = pd.DataFrame(similar_molecules, columns=['SMILES', 'Similarity'])
    df_results.to_csv('similar_molecules.csv', index=False)
    print("Results saved to similar_molecules.csv")
    
    conn.close()
else:
    print("Invalid SMILES input.")
# Out:
# Enter SMILES to search for similar molecules:  Nc1c(sc2nc(N)c(cc12)C#N)C(=O)Nc1ccccc1Br
# Enter similarity threshold (0 to 1):  0.1
# Similar molecules to Nc1c(sc2nc(N)c(cc12)C#N)C(=O)Nc1ccccc1Br with a similarity threshold of 0.1:
# SMILES: Nc1c(C(Nc(cccc2)c2Br)=O)sc(nc2N)c1cc2C#N, Similarity: 1.00
# SMILES: Nc(c1c2)c(C(Nc(cccc3)c3Oc3ccccc3)=O)sc1nc(N)c2C#N, Similarity: 0.71
# SMILES: Nc1c(C(NCc2cccc(Cl)c2)=O)sc(nc2N)c1cc2C#N, Similarity: 0.57
# SMILES: Cc1c(c(N)c(C(Nc(cccc2)c2OC)=O)s2)c2nc(C)c1, Similarity: 0.40
# SMILES: CCOc(cccc1)c1NC(c(sc1nc(C)cc(C)c11)c1N)=O, Similarity: 0.38
# SMILES: Cc1cc(COC)c(c(N)c(C(Nc(cccc2)c2O)=O)s2)c2n1, Similarity: 0.38
# SMILES: Cc1cc(COC)c(c(N)c(C(Nc(cccc2)c2C(OC)=O)=O)s2)c2n1, Similarity: 0.37
# SMILES: COc(cc1)cc(NC(c(sc2nc(-c(cc3)ccc3F)ccc22)c2N)=O)c1OC, Similarity: 0.36
# SMILES: COc(ccc(Cl)c1)c1NC(c(sc1c2ccc(-c(cc3)cc(OC)c3OC)n1)c2N)=O, Similarity: 0.36
# SMILES: Nc1c(C(Nc(c(Cl)ccc2)c2Cl)=O)sc2c1ccc(-c1cnccc1)n2, Similarity: 0.35
# SMILES: Nc1c(C(Nc2nccs2)=O)sc2nc(CCCCC3)c3cc12, Similarity: 0.35
# SMILES: Cc1cc(COC)c(c(N)c(C(Nc(cc2)ccc2C#N)=O)s2)c2n1, Similarity: 0.35
# SMILES: COc(ccc(-c(cc1)nc2c1c(N)c(C(Nc(ccc(F)c1)c1Cl)=O)s2)c1)c1OC, Similarity: 0.34
# SMILES: Cc1c(c(N)c(C(Nc(ccc(OC)c2)c2OC)=O)s2)c2nc(C)c1, Similarity: 0.33
# SMILES: Cc1cc(COC)c(c(N)c(C(Nc2cccc3cccnc23)=O)s2)c2n1, Similarity: 0.33
# SMILES: Cc1cc(COC)c(c(N)c(C(Nc(cccc2)c2N2CCOCC2)=O)s2)c2n1, Similarity: 0.33
# SMILES: CCc1cccc(CC)c1NC(c(sc1nc(C)cc(C)c11)c1N)=O, Similarity: 0.33
# SMILES: COc(ccc(Cl)c1)c1NC(c(sc1c2ccc(-c(cc3)cc4c3OCO4)n1)c2N)=O, Similarity: 0.33
# SMILES: Cc1c(c(N)c(C(NCc2ccccc2)=O)s2)c2nc(C)c1, Similarity: 0.32
# SMILES: Cc(sc(C(Nc(cccc1)c1C#N)=O)c1)c1S(N1CCCC1)(=O)=O, Similarity: 0.31
# SMILES: Cc1cc(C)nc2c1c(N)c(C(Nc1cc(Cl)c(C)cc1)=O)s2, Similarity: 0.31
# SMILES: Nc1c(C(Nc2ccccc2)=O)sc2nc(-c3ccccc3)cc(-c(cc3)cc4c3OCO4)c12, Similarity: 0.31
# SMILES: Cc1cc(NC(c(sc2nc(C)c(C)c(C)c22)c2N)=O)no1, Similarity: 0.30
# SMILES: Cc1nc(sc(C(Nc2cccc(Cl)c2)=O)c2N)c2c(COC)c1, Similarity: 0.29
# SMILES: Cc1cc(COC)c(c(N)c(C(Nc2cc(F)ccc2)=O)s2)c2n1, Similarity: 0.29
# SMILES: Cc1cc(COC)c(c(N)c(C(Nc(cc2)ccc2OC)=O)s2)c2n1, Similarity: 0.29
# SMILES: N#Cc(c(F)c1)cc(F)c1NC(c1nsc(Cl)c1Cl)=O, Similarity: 0.29
# SMILES: Cc1c(C(Nc(cccc2)c2Cl)=O)sc(NC(c(cccc2)c2Cl)=O)n1, Similarity: 0.29
# SMILES: N#Cc(cccc1)c1NC(NC(c1cnccc1)=O)=S, Similarity: 0.29
# SMILES: CCOC(c(sc(c1c2-c(cc3)cc(OC)c3OC)nc(N)c2C#N)c1N)=O, Similarity: 0.29
# SMILES: Cc1nnc2sc(-c(cccc3)c3NC(c(sc3c4cccc3)c4Cl)=O)nn12, Similarity: 0.29
# SMILES: CC(Nc1nnc(SCc(cccc2)c2C#N)s1)=O, Similarity: 0.28
# SMILES: Cc1nnc2sc(-c(cccc3)c3NC(c3cc(OC)cc(OC)c3)=O)nn12, Similarity: 0.28
# SMILES: Cc1c(C(Nc(cccc2)c2Cl)=O)sc(NC(c2ccncc2)=O)n1, Similarity: 0.28
# SMILES: N#Cc(cccc1)c1NC(CN1CCN(Cc2ccccc2)CC1)=O, Similarity: 0.28
# SMILES: CCOC(c(cc1)ccc1NC(c(sc1nc(C)cc(COC)c11)c1N)=O)=O, Similarity: 0.28
# SMILES: Cc1nnc2sc(-c(cccc3)c3NC(c3cc(cccc4)c4o3)=O)nn12, Similarity: 0.27
# SMILES: O=C(CN(CC1)CCC1C(c1ccccc1)=O)Nc(cccc1)c1Br, Similarity: 0.27
# SMILES: CC(Nc1c(C2c3ccco3)c(N)c(C#N)s1)=C2C(Nc(cccc1)c1OC)=O, Similarity: 0.27
# SMILES: Cc1c(c(N)c(C(c(cc2)ccc2F)=O)s2)c2nc(C)c1C(Nc1ccccc1)=O, Similarity: 0.27
# SMILES: COc(ccc(Cl)c1)c1NC(c(sc1c2cccc1)c2Cl)=O, Similarity: 0.26
# SMILES: O=C(CN(CC1)CCN1c1cc(Cl)ccc1)Nc(cccc1)c1Br, Similarity: 0.26
# SMILES: CC(C1)Nc2nc(C(Nc(cc(cc3)Cl)c3C#N)=O)nn2C1C(F)F, Similarity: 0.26
# SMILES: Cc1nc(cccc2)c2n1C1CCN(CC(Nc(cccc2)c2Br)=O)CC1, Similarity: 0.26
# SMILES: N#Cc(c(SCC(Nc(cccc1)c1N1CCCCC1)=O)nc1c2)cc1cc1c2OCO1, Similarity: 0.26
# SMILES: CC(c1c(C)nc(NC(c2cc(cccc3)c3o2)=O)s1)=O, Similarity: 0.25
# SMILES: CCC(Nc(cc1)cc(NC(c(sc2c3cccc2)c3Cl)=O)c1Cl)=O, Similarity: 0.25
# SMILES: CCOc(cc1cc2C#N)ccc1nc2SCC(Nc(cccc1)c1F)=O, Similarity: 0.25
# SMILES: CCOc(cc1cc2C#N)ccc1nc2SCC(Nc(cccc1)c1Cl)=O, Similarity: 0.25
# SMILES: Cc(cccc1)c1C(Nc(sc1c2CCCC1)c2C#N)=O, Similarity: 0.25
# SMILES: N#Cc(cccc1)c1NC(CC1Sc(ccc(C(F)(F)F)c2)c2NC1=O)=O, Similarity: 0.25
# SMILES: COc(cc1)ccc1-c(cc(-c1ccccc1)nc1N)c1C#N, Similarity: 0.25
# SMILES: Cc(cc(C)nc1SCC(Nc(cccc2)c2OC)=O)c1C#N, Similarity: 0.24
# SMILES: Cc1c(C(OC)=O)sc(NC(c(cc(cc2)Br)c2Cl)=O)n1, Similarity: 0.24
# SMILES: O=C(c1cc(cccc2)c2o1)Nc1nc(cccc2)c2s1, Similarity: 0.24
# SMILES: N#Cc(c(N(CCC1)CCN1C(Nc(cccc1)c1Cl)=O)nc1c2)cc1cc1c2OCO1, Similarity: 0.24
# SMILES: Cc(occ1)c1-c(n1C)nnc1SCC(Nc(cccc1)c1Br)=O, Similarity: 0.24
# SMILES: N#Cc(ccc(NC(c1c(-c(cccc2)c2F)ocn1)=O)c1)c1Cl, Similarity: 0.24
# SMILES: Cc1cccc(NC(Cn2c(cccc3)c3c(C#N)c2)=O)c1, Similarity: 0.24
# SMILES: Cc1cccc(C(Nc(sc2c3CCC2)c3C#N)=O)c1, Similarity: 0.24
# SMILES: Cc1nc2ccccc2c(C(Nc2nc(cccc3)c3s2)=O)c1, Similarity: 0.24
# SMILES: O=C(c1cc(cccc2)c2o1)Nc(cccc1)c1OC(F)F, Similarity: 0.24
# SMILES: O=C(c1c(cccc2Br)c2ccc1)Nc1cc(Cl)ccc1, Similarity: 0.24
# SMILES: Cc(cc(cc1)Br)c1NC(c1ccco1)=O, Similarity: 0.24
# SMILES: COc(cccc1)c1NC(NCCCNc(c(C#N)cc1c2)nc1cc1c2OCO1)=O, Similarity: 0.24
# SMILES: COc(cc1)ccc1C(Nc(cccc1)c1C(Nc1ncccc1)=O)=O, Similarity: 0.24
# SMILES: CC(Nc(cc1)ccc1NC(c(sc1c2cccc1)c2Cl)=O)=O, Similarity: 0.24
# SMILES: Nc(cc1)ccc1C(Nc(c(N)cc(N)c1)c1Br)=O, Similarity: 0.23
# SMILES: CCOC(c1c(C)nc(NC(c2cc(cccc3)c3o2)=O)s1)=O, Similarity: 0.23
# SMILES: COc(cccc1)c1-c(cc(-c(cc1)ccc1O)nc1N)c1C#N, Similarity: 0.23
# SMILES: CC(C)C(Nc1cccc(NC(c(sc2c3cccc2)c3Cl)=O)c1)=O, Similarity: 0.23
# SMILES: CCC(Nc1cccc(NC(c(sc2c3cccc2)c3Cl)=O)c1)=O, Similarity: 0.23
# SMILES: NC(c(sc1nc(CCC2)c2c(-c2cnccc2)c11)c1N)=O, Similarity: 0.23
# SMILES: COc(cccc1)c1NC(c1cn(CCC#N)nc1-c1cc(cccc2)c2o1)=O, Similarity: 0.23
# SMILES: Cc(cc(C)nc1SCC(Nc2ccccc2)=O)c1C#N, Similarity: 0.23
# SMILES: CCc1c(C)sc(NC(c(cccc2)c2Br)=O)c1C(OC)=O, Similarity: 0.23
# SMILES: Cc1cccc(NC(c(cccc2)c2NC(c(cc2)ccc2OC)=O)=O)n1, Similarity: 0.23
# SMILES: Cc(sc(C(Nc(cccc1)c1C(O)=O)=O)c1)c1S(N(C)C)(=O)=O, Similarity: 0.23
# SMILES: N#CCC(Nc1ncc(Cc(cccc2)c2Cl)s1)=O, Similarity: 0.23
# SMILES: N#Cc(c(NCCCNC(Nc1ccccc1)=O)nc1c2)cc1cc1c2OCO1, Similarity: 0.23
# SMILES: O=C(c1ccco1)Nc(cc1)ccc1NC(c1c(cccc2Br)c2ccc1)=O, Similarity: 0.23
# SMILES: Cc1c(C(Nc2c(C)c(C)ccc2)=O)sc(NC(c2ccco2)=O)c1C(OC)=O, Similarity: 0.23
# SMILES: N#Cc(ccc(NC(c1c(-c2cc(Cl)ccc2)ocn1)=O)c1)c1Cl, Similarity: 0.23
# SMILES: CC(CC1)Cc2c1c(C#N)c(NC(c1ccco1)=O)s2, Similarity: 0.23
# SMILES: Cc1c(C(Nc2cc(OC)ccc2)=O)sc(NC(c(cccc2)c2Cl)=O)n1, Similarity: 0.23
# SMILES: O=C(c1ccco1)Nc1c(C(F)(F)F)cccc1, Similarity: 0.23
# SMILES: O=C(c1c(cccc2Br)c2ccc1)Nc(cc1)ccc1Cl, Similarity: 0.23
# SMILES: O=C(c1csc2c1CCCC2)Nc1cccc2cccnc12, Similarity: 0.23
# SMILES: COc(cc1)ccc1C(Nc(sc1c2CCC1)c2C#N)=O, Similarity: 0.23
# SMILES: COc(cc(cc1)-c2cc(-c(cc3)ccc3Br)nc(N)c2C#N)c1O, Similarity: 0.23
# SMILES: CC(c1cccc(NC(CSc(c(C#N)cc2c3)nc2ccc3OC)=O)c1)=O, Similarity: 0.23
# SMILES: CC(C)(Cc1c23)OCc1c(N1CCOCC1)nc2sc(C(NCc1ccco1)=O)c3N, Similarity: 0.23
# SMILES: CCC(Nc(cc1)ccc1NC(c(sc1c2cccc1)c2Cl)=O)=O, Similarity: 0.23
# SMILES: Cc1nc2cc(NC(Nc3ccccc3)=O)c(C)nc2n1Cc(cc1)ccc1Br, Similarity: 0.23
# SMILES: Cc1nnc2sc(-c3cc(NC(c4ccco4)=O)c(C)cc3)nn12, Similarity: 0.23
# SMILES: CCOC(C(N1)=C(CNc(cccc2)c2C#N)NC1=O)=O, Similarity: 0.22
# SMILES: O=C(c1cc2nc(-c3cocc3)c(-c3cocc3)nc2cc1)Nc(cccc1)c1F, Similarity: 0.22
# SMILES: Cc(cccc1cc2C#N)c1nc2SCC(NC(C(N1)=O)=CNC1=O)=O, Similarity: 0.22
# SMILES: Cc1cc(sc(C(Nc2cc(N)ccc2)=O)c2)c2cc1, Similarity: 0.22
# SMILES: CN(Cc1ccccc1)S(c1csc(C(Nc(cc2)ccc2C#N)=O)c1)(=O)=O, Similarity: 0.22
# SMILES: N#Cc1c(SCC(Nc2c(C(F)(F)F)cccc2)=O)sc(C(O)=C2)c1NC2=O, Similarity: 0.22
# SMILES: Cc1ccc(cc(c(SCC(Nc2cc(C)cc(C)c2)=O)n2)C#N)c2c1, Similarity: 0.22
# SMILES: O=C(c1ccco1)Nc1c(c(CCC2)c2s2)c2ncn1, Similarity: 0.22
# SMILES: CCOc(cc(cc1)-c(cc(-c2ccccc2)nc2N)c2C#N)c1O, Similarity: 0.22
# SMILES: Nc(sc(-c1ccccc1)c1)c1C(NCC(O)=O)=O, Similarity: 0.22
# SMILES: CC(N(c1nc(-c2ccccc2)c(-c2ccccc2)s1)c1ccccc1)=O, Similarity: 0.22
# SMILES: Cc1ccc(cc(c(SCC(Nc2nccs2)=O)n2)C#N)c2c1, Similarity: 0.22
# SMILES: Cc(nc(Nc1nc(cccc2)c2s1)nc1)c1C(Nc(cccc1)c1OC)=O, Similarity: 0.22
# SMILES: Cc1c(C(OC)=O)sc(NC(c(cc2)ccc2Cl)=O)c1C#N, Similarity: 0.22
# SMILES: O=C(c1ccco1)Nc1nc(ccc(Cl)c2)c2s1, Similarity: 0.22
# SMILES: Cc(cccc1)c1NC(C(Cc1cccs1)C#N)=O, Similarity: 0.22
# SMILES: CCc(cccc1)c1NC(NC1=CC=CN(Cc(cccc2)c2Br)C1=O)=O, Similarity: 0.22
# SMILES: O=C(c1cnccc1)Nc(cccc1)c1N1CCOCC1, Similarity: 0.22
# SMILES: CN1C(SCC(Nc2cccc3ccccc23)=O)=Nc(sc2c3CCC2)c3C1=O, Similarity: 0.22
# SMILES: N#Cc(c(SCC(c1ccccc1)=O)nc1c2)cc1cc1c2OCO1, Similarity: 0.22
# SMILES: O=C(c(cc1)ccc1F)Nc1cccc2nsnc12, Similarity: 0.22
# SMILES: CCc1cc(C(N(Cc2ccco2)C(SCC(N)=O)=N2)=O)c2s1, Similarity: 0.22
# SMILES: CCOC(c(sc1nc(C)cc(COC)c11)c1N)=O, Similarity: 0.22
# SMILES: CCCCCC(Nc(cc1)ccc1C(Nc1cccc2ccccc12)=O)=O, Similarity: 0.22
# SMILES: CCOC(c(sc1nc(C)cc(C(F)(F)F)c11)c1N)=O, Similarity: 0.22
# SMILES: Cc1cc(C)c(C(Nc2nc(ccc(OC)c3)c3s2)=O)c(C)c1, Similarity: 0.22
# SMILES: CC(C)(C1)OCc(c(N2CCOCC2)n2)c1c1c2sc(C(c(cc2)ccc2Br)=O)c1N, Similarity: 0.22
# SMILES: COc(cccc1)c1C(NCCCNc(c(C#N)cc1c2)nc1cc1c2OCO1)=O, Similarity: 0.22
# SMILES: COC(c(cc1)ccc1NC(c1c(cccc2Br)c2ccc1)=O)=O, Similarity: 0.21
# SMILES: CCN(CC1)Cc2c1c(C#N)c(NC(NC(c1ccccc1)=O)=S)s2, Similarity: 0.21
# SMILES: O=C(c([nH]nc1)c1Br)N/N=C/c1ccccc1, Similarity: 0.21
# SMILES: O=C(c1cnccc1)Nc1nc(cccc2)c2s1, Similarity: 0.21
# SMILES: Cc1nnc(NC(Nc(cccc2)c2OC)=O)s1, Similarity: 0.21
# SMILES: CCOc(cccc1)c1NC(c1c(C)c(C(OC)=O)c(NC(c(cc2)cc3c2OCO3)=O)s1)=O, Similarity: 0.21
# SMILES: CCOc(cc1)cc2c1nc(NC(c1ccccc1)=O)s2, Similarity: 0.21
# SMILES: Cn(c(C(Nc(cccc1)c1C(OC)=O)=O)c1)c2c1scc2, Similarity: 0.21
# SMILES: O=C(c(cc1)cnc1Nc1cc(Cl)ccc1)Nc(cccc1)c1Cl, Similarity: 0.21
# SMILES: CC(N(CC1)CCN1c(cccc1)c1NC(c(cc1)cc(Cl)c1Cl)=O)=O, Similarity: 0.21
# SMILES: COc1cccc(OC(CSc2nnc(-c(cccc3)c3Br)o2)=O)c1, Similarity: 0.21
# SMILES: CC(C(NCc1ccccc1)=O)N(C(c(snc1C(N)=O)c1N)=O)c(cc1)ccc1F, Similarity: 0.21
# SMILES: Cc1cc(NC(Nc(cccc2)c2OC)=O)ncc1, Similarity: 0.21
# SMILES: CC(C)C(N(CC1)CCN1c(cccc1)c1NC(c1ccccc1)=O)=O, Similarity: 0.21
# SMILES: CCOc(cc(c(OCC)c1)NC(c2ncccc2)=O)c1NC(c1cccs1)=O, Similarity: 0.21
# SMILES: Cc(cc1cc2C#N)c(C)cc1nc2NCCNC(CCC(O)=O)=O, Similarity: 0.21
# SMILES: Cn1c(SCC(Nc(cccc2)c2OC)=O)nnc1-c(cccc1)c1Br, Similarity: 0.21
# SMILES: CCOc1ccc(cc(c(SCC(N(c2ccccc2)c2ccccc2)=O)n2)C#N)c2c1, Similarity: 0.21
# SMILES: CCN(CC)CCOc(cccc1)c1NC(c1csc(NC(C)=O)n1)=O, Similarity: 0.21
# SMILES: Nc1nonc1-c1nc(cccc2)c2n1CC(Nc(cccc1)c1F)=O, Similarity: 0.21
# SMILES: NC(c(sc1nc(-c(cc2)cc3c2OCCO3)cc(C(F)(F)F)c11)c1N)=O, Similarity: 0.21
# SMILES: NC(c1nc(-c(cc2)ccc2C#N)nc(N2Cc3ccccc3)c1NC2=O)=O, Similarity: 0.21
# SMILES: CCOc(cccc1)c1C(Nc1nc(ccc(S(C)(=O)=O)c2)c2s1)=O, Similarity: 0.21
# SMILES: NC(c1c(NC(C2=Cc(cccc3)c3OC2=O)=O)sc2c1CCCC2)=O, Similarity: 0.21
# SMILES: Cc(sc(C(Nc(cccc1)c1C(O)=O)=O)c1)c1S(N1CCOCC1)(=O)=O, Similarity: 0.21
# SMILES: CCc1cc(C(N(Cc2ccco2)C(SCC(OCC)=O)=N2)=O)c2s1, Similarity: 0.21
# SMILES: COc(cc1)ccc1C(Nc(cc1)cc(NC(c2ccccc2)=O)c1Cl)=O, Similarity: 0.21
# SMILES: Cc1cc(C)c(cc(c(NCCCN)n2)C#N)c2c1, Similarity: 0.21
# SMILES: CSc1nsc(NC(Nc(cccc2)c2Cl)=O)n1, Similarity: 0.21
# SMILES: CC(C(Nc1cccc2ccccc12)=O)Sc1nnc(-c2ccccc2)c(-c2ccccc2)n1, Similarity: 0.21
# SMILES: CCc1nnc(NC(C2=Cc(cccc3)c3OC2=O)=O)s1, Similarity: 0.21
# SMILES: Cc(ccc(NC(c1cccs1)=O)c1)c1NC(c1cc(N)ccc1)=O, Similarity: 0.21
# SMILES: CCOC(c1c(C)nc(NC(NC(c2ccccc2)=O)=S)s1)=O, Similarity: 0.21
# SMILES: CCC(Nc(cc1)cc2c1N=C(C)N(Cc1ccccc1)C2=O)=O, Similarity: 0.21
# SMILES: CCC(Nc(cc1)cc(NC(c2cc(cccc3)c3o2)=O)c1Cl)=O, Similarity: 0.21
# SMILES: CCc(nc1SCC(c(cc2)ccc2F)=O)c(C)cc1C#N, Similarity: 0.21
# SMILES: CC(C(Nc1cc(Cl)ccc1)=O)Sc1nnc(-c(cccc2)c2Br)o1, Similarity: 0.21
# SMILES: N#Cc(cc1)ccc1NC(Nc(cc1)cc(OC2)c1N(Cc1ccccc1)C2=O)=O, Similarity: 0.21
# SMILES: CSc1cc(-n2nnc(C(Nc(ccc(F)c3)c3F)=O)c2N)ccc1, Similarity: 0.21
# SMILES: Cc(cc1)cc2c1oc(-c1cccc(NC(c(cccc3)c3OC)=O)c1C)n2, Similarity: 0.21
# SMILES: COc(cccc1)c1NC(c1nn2c(C(F)(F)F)cc(-c3ccco3)nc2c1)=O, Similarity: 0.21
# SMILES: N#Cc(c(NCCNC(Nc(ccc(F)c1)c1F)=O)nc1c2)cc1cc1c2OCO1, Similarity: 0.21
# SMILES: CCc1cc(C(N(Cc2ccco2)C(SCC(NCc2ccco2)=O)=N2)=O)c2s1, Similarity: 0.21
# SMILES: O=C(c(sc1c2cccc1)c2Cl)NC1CC1, Similarity: 0.21
# SMILES: COc(cc1)ccc1-c(nc1N)cc(-c(cc2)cc(OC)c2OC)c1C#N, Similarity: 0.21
# SMILES: Cc1c(cc(c(N(CC2)CCC2O)n2)C#N)c2c(C)cc1, Similarity: 0.21
# SMILES: Cc1csc(NC(CS(Cc2ccccc2)(=O)=O)=O)n1, Similarity: 0.21
# SMILES: O=C(COc1cc2ccccc2cc1)Nc1cccc2cccnc12, Similarity: 0.21
# SMILES: O=C(Nc1cccc2ccccc12)OC(C1)C=CS1(=O)=O, Similarity: 0.21
# SMILES: O=C(c1cccc2ccccc12)Nc1ncc(Cc(cccc2)c2Cl)s1, Similarity: 0.21
# SMILES: Cc1c(C(Nc2cc(CCC3)c3cc2)=O)sc(NC(C2CC2)=O)n1, Similarity: 0.21
# SMILES: O=C(c1c(-c(cc2)ccc2F)ocn1)Nc1c(Cc2ccccc2)cccc1, Similarity: 0.21
# SMILES: Cc1c(C(Nc2cnccc2)=O)sc(NC(c(cc2)ccc2Cl)=O)n1, Similarity: 0.21
# SMILES: COc(cc1)ccc1NC(c1cc(-c2ncccc2)nc2ccccc12)=O, Similarity: 0.21
# SMILES: CCOC(c1c(-c2ccccc2)n2ncc(C#N)c2nc1)=O, Similarity: 0.21
# SMILES: Cc(cc1)cc2c1oc(-c1cc(NC(c3ccccc3)=O)c(C)cc1)n2, Similarity: 0.21
# SMILES: CCc(cccc1)c1NC(c(cc1)cc(CC2)c1N2S(C)(=O)=O)=O, Similarity: 0.21
# SMILES: CCCCc1nc2cc(NC(Nc3ccccc3)=O)c(C)nc2n1Cc1ccccc1, Similarity: 0.20
# SMILES: Cc(cc1)cc(Br)c1NC(CSc1nnc(-c2cc(O)ccc2)o1)=O, Similarity: 0.20
# SMILES: Cc(cccc1cc2C#N)c1nc2NCCNC(NC1CCCCC1)=O, Similarity: 0.20
# SMILES: Cc1ccc(cc(c(NCCNC(c2nccnc2)=O)n2)C#N)c2c1, Similarity: 0.20
# SMILES: Cc(ccc(-c(s1)nn2c1nnc2)c1)c1NC(c(o1)ccc1Br)=O, Similarity: 0.20
# SMILES: Cc1ccc(cc(c(NCCNS(c2cccc3ccccc23)(=O)=O)n2)C#N)c2c1, Similarity: 0.20
# SMILES: Cc(c(NC(CSc(sc(C(O)=C1)c2NC1=O)c2C#N)=O)ccc1)c1Cl, Similarity: 0.20
# SMILES: CCc1cc(C(N(Cc2ccco2)C(SCC(Nc2nccs2)=O)=N2)=O)c2s1, Similarity: 0.20
# SMILES: NC(c1ccc(-c(cccc2)c2Br)o1)=O, Similarity: 0.20
# SMILES: O=C(COc(cccc1)c1Br)Nc1cc(C(F)(F)F)ccc1, Similarity: 0.20
# SMILES: CCOc1cccc(C(Nc(cc2)ncc2Br)=O)c1, Similarity: 0.20
# SMILES: S=C1Oc(ccc(Cl)c2)c2N1CNc(cccc1)c1Br, Similarity: 0.20
# SMILES: Oc(cc(cc1)NC(c(cc2)ccc2Br)=O)c1C(Oc1ccccc1)=O, Similarity: 0.20
# SMILES: CC(C)C(N(CC1)CCN1c(cccc1)c1NC(c1ccc(C)cc1)=O)=O, Similarity: 0.20
# SMILES: CC(CCCc1c2-c3ccccc3)c1nc(N)c2C#N, Similarity: 0.20
# SMILES: Cc(cc1cc2C#N)ccc1nc2SCC(OCCOC)=O, Similarity: 0.20
# SMILES: CC(C(Nc1ccc(C)cc1)=O)Sc1nnc(-c(cccc2)c2Br)o1, Similarity: 0.20
# SMILES: O=C(c1cccc2c1[nH]c(C(F)(F)F)n2)Nc1c[nH]c2c1cccc2, Similarity: 0.20
# SMILES: CCC(C)NC(c(cc1)cc2c1nc(NC(c(cc1)ccc1N)=O)s2)=O, Similarity: 0.20
# SMILES: Cc(cc(cc1)NC(c2cc(OC)ccc2)=O)c1NC(c1ccco1)=O, Similarity: 0.20
# SMILES: Cc(sc(C(Nc(cc1)ccc1C#N)=O)c1)c1S(N1CCCC1)(=O)=O, Similarity: 0.20
# SMILES: COc1cccc(C(Nc(cc2)cc(OC)c2NC(c2ccco2)=O)=O)c1, Similarity: 0.20
# SMILES: COc1cc(C(NCCNc(c(C#N)cc2c3)nc2cc2c3OCO2)=O)cc(OC)c1, Similarity: 0.20
# SMILES: Cc(cccc1)c1NC(c(cc1)cc(N2)c1N(Cc(cc1)ccc1OC)C2=O)=O, Similarity: 0.20
# SMILES: Cc1cc(C)c(cc(c(N(CCC2)CCN2S(c2ccccc2)(=O)=O)n2)C#N)c2c1, Similarity: 0.20
# SMILES: CCOc(cc1)ccc1N(C(C)C(NCc1ccccc1)=O)C(c(snc1C(N)=O)c1N)=O, Similarity: 0.20
# SMILES: Cc1c(C)sc(N=C(N2CCOC)SCC(Nc(cccc3)c3OC)=O)c1C2=O, Similarity: 0.20
# SMILES: OC(c1c(NC(c2ccccc2)=O)sc2c1CCC2)=O, Similarity: 0.20
# SMILES: O=C(c1ccc(-c(cc2)ccc2Cl)o1)Nc(cccc1)c1Cl, Similarity: 0.20
# SMILES: COc(ccc(-c1nc(cccc2)c2o1)c1)c1NC(c(cc1)cc(OC)c1OC)=O, Similarity: 0.20
# SMILES: COc(ccc(/C=N/NC(c(sc1c2cccc1)c2Cl)=O)c1)c1OC, Similarity: 0.20
# SMILES: CC(c1cccc(S(N(CC2)CCN2c2nc3cc(C)c(C)cc3cc2C#N)(=O)=O)c1)=O, Similarity: 0.20
# SMILES: CC(c(ccc(OC(c(cccc1)c1Br)=O)c1)c1O1)=CC1=O, Similarity: 0.20
# SMILES: O=C(c(c1ccccc11)ccc1Br)F, Similarity: 0.20
# SMILES: N#Cc(c(NCCNC(Nc(cc1)ccc1Cl)=O)nc1c2)cc1cc1c2OCO1, Similarity: 0.20
# SMILES: COc(cccc1)c1NC(Nc1nnc(-c2ccncc2)s1)=O, Similarity: 0.20
# SMILES: COC(CCC(Nc(cccc1)c1C(Nc1ccccc1)=O)=O)=O, Similarity: 0.20
# SMILES: Cc(cc1cc2C#N)ccc1nc2NCCCNC(c1nccnc1)=O, Similarity: 0.20
# SMILES: Cc(cccc1)c1NC(c1cc(S(N(C)c(cc2)ccc2F)(=O)=O)cs1)=O, Similarity: 0.20
# SMILES: Cc(ccc1nsnc11)c1NC(c1cccc2ccccc12)=O, Similarity: 0.20
# SMILES: C/C(/c1cc2ccccc2cc1)=N/NC(c1cc(Br)cnc1)=O, Similarity: 0.20
# SMILES: CCOC(c1c(C)c(C#N)c(NC(COc2c(C)cccc2C)=O)s1)=O, Similarity: 0.20
# SMILES: Cc(c1c2sc(C(Nc3nccs3)=O)c1)nn2-c1ccccc1, Similarity: 0.20
# SMILES: OC(c(cc1)cc(S(NCc2ccccc2)(=O)=O)c1Br)=O, Similarity: 0.20
# SMILES: COc(cc(cc1)-c(cc(-c(cc2)ccc2O)nc2N)c2C#N)c1O, Similarity: 0.20
# SMILES: Cc1cccc(-c2c(C(Nc3cccc4ncccc34)=O)nco2)c1, Similarity: 0.20
# SMILES: Cc(nc1C(N)=O)nc(N2c3cc(C#N)ccc3)c1NC2=O, Similarity: 0.20
# SMILES: CC(C1)N(C(CS(c(cccc2)c2NC(c2cc(c(C)nn3-c4ccccc4)c3s2)=O)(=O)=O)=O)c2c1cccc2, Similarity: 0.20
# SMILES: COc(cc1)ccc1NC(N(CCC1)CCN1c(c(C#N)cc1c2)nc1cc1c2OCO1)=O, Similarity: 0.20
# SMILES: COc(cc(cc(c(SCC(N(CC1)CCN1c1ccccc1)=O)n1)C#N)c1c1)c1OC, Similarity: 0.20
# SMILES: N#Cc(c(NCCNC(c(ccc(F)c1)c1F)=O)nc1c2)cc1cc1c2OCO1, Similarity: 0.20
# SMILES: Nc1nc(-c2c(CC3)cccc2)c3c(-c(cc2)cc3c2OCO3)c1C#N, Similarity: 0.20
# SMILES: O=C(c1cccc2nccnc12)Nc(ccc(N1CCOCC1)c1)c1N1CCOCC1, Similarity: 0.20
# SMILES: O=C(c(cnn1c(C(F)F)c2)c1nc2-c1ccccc1)Nc1cnccc1, Similarity: 0.20
# SMILES: COc(cccc1)c1NC(Nc1nc(-c2cnccc2)nc2ccccc12)=O, Similarity: 0.20
# SMILES: O=C(c1cc(cccc2)c2o1)Nc1cc(-c2nc(cccc3)c3o2)ccc1, Similarity: 0.20
# SMILES: O=C1Oc(cccc2)c2C=C1c1nnc(Nc2cccc3ccccc23)s1, Similarity: 0.20
# SMILES: O=C(c1ccco1)NC(Nc1cccc2nsnc12)=S, Similarity: 0.20
# SMILES: CN(CC1)CCN1C(c(cccc1)c1NC(c(ccc(Cl)c1)c1Cl)=O)=O, Similarity: 0.20
# SMILES: Cc(c(NC(c1cc(scc2)c2n1C)=O)ccc1)c1Cl, Similarity: 0.20
# SMILES: CSc1nsc(SCC(Nc(cccc2)c2C(O)=O)=O)n1, Similarity: 0.20
# SMILES: CC(NCCCNc1nc2c(C)cc(C)cc2cc1C#N)=O, Similarity: 0.20
# SMILES: Cc(cccc1cc2C#N)c1nc2Oc(cc1)ccc1OC, Similarity: 0.20
# SMILES: CC(Cc1ccccc1)NC(c1cc(cccc2)c2o1)=O, Similarity: 0.20
# SMILES: O=C1OC(c(cccc2)c2Br)=Nc(cc2)c1cc2Cl, Similarity: 0.20
# SMILES: CC(C)(C)c(cc1)ccc1C(Nc1nc(C)c(C(C)=O)s1)=O, Similarity: 0.20
# SMILES: CCc1cc(C(N(CCO)C(CC)=N2)=O)c2s1, Similarity: 0.20
# SMILES: O=C(c1cc(cccc2)c2o1)Nc(cc1)cc(C=C2)c1OC2=O, Similarity: 0.20
# SMILES: CC(Nc1ccc(C(c2ccccc2)C#N)cc1)=O, Similarity: 0.20
# SMILES: CN(CC1)Cc(c(-c2cccs2)c2C#N)c1nc2SCC(Nc1cc(F)ccc1)=O, Similarity: 0.20
# SMILES: COc(cc(cc(c(SCC(Nc(cc1)cc(Cl)c1F)=O)n1)C#N)c1c1)c1OC, Similarity: 0.20
# SMILES: CCN(CC)c(c(NC(C1CC1)=O)c1)cc(N=C(C)N2Cc3ccccc3)c1C2=O, Similarity: 0.20
# SMILES: Cc(cc(cc1)-c2nc(nccc3)c3o2)c1NC(c(cc(cc1C)Br)c1OC)=O, Similarity: 0.20
# SMILES: COc1ccc(cc(c(SCC(N2CCCCC2)=O)n2)C#N)c2c1, Similarity: 0.20
# SMILES: CN(c(nc(c(C#N)c1-c(cc2)cc(Cl)c2OC)N)c1C(N1C)=O)C1=O, Similarity: 0.20
# SMILES: Cc1c(-c2c(C)cc(C)cc2)nc(NC(c2cccs2)=O)s1, Similarity: 0.19
# SMILES: Cc1cccc(C)c1NC(C(c1ccco1)NC(c(cccc1)c1Br)=O)=O, Similarity: 0.19
# SMILES: CCOc(cc(cc1)-c(cc(-c(cc2)ccc2N)nc2N)c2C#N)c1O, Similarity: 0.19
# SMILES: Cc(cc(C)nc1SCC(c2cccs2)=O)c1C#N, Similarity: 0.19
# SMILES: Cc(cc1cc2C#N)ccc1nc2Nc(ccc(OC)c1)c1OC, Similarity: 0.19
# SMILES: O=C(c1ccco1)Nc(cc1)cc(Cl)c1NC(c1cccs1)=O, Similarity: 0.19
# SMILES: Cc(cc1)ccc1C(C1CCN(CC(Nc(ccc(C)c2)c2Br)=O)CC1)=O, Similarity: 0.19
# SMILES: COc1cc(C(Nc2c(C(N)=O)c(CCCCC3)c3s2)=O)cc(OC)c1, Similarity: 0.19
# SMILES: Cc1c(C(NCc2ccccc2)=O)c2ccccc2nc1-c1ccccc1, Similarity: 0.19
# SMILES: CCOC(c1c(N)sc2c1ccc(Br)c2O)=O, Similarity: 0.19
# SMILES: NS(c1cc(C(N/N=C/c2ccccc2)=O)ccc1)(=O)=O, Similarity: 0.19
# SMILES: Cc1csc(NC(CCCc2ccccc2)=O)n1, Similarity: 0.19
# SMILES: COC(c(cc(c(OC)c1)OC)c1NC(c1ccco1)=O)=O, Similarity: 0.19
# SMILES: CC(C(NCc(cc1)ccc1F)=O)N(C(c(snc1C(NC2CCCC2)=O)c1N)=O)c1cccc2ccccc12, Similarity: 0.19
# SMILES: CCOC(c1c(NC(CSc2nc(C)cc(C)c2C#N)=O)sc(C(C)=O)c1C)=O, Similarity: 0.19
# SMILES: N#Cc(c(SCC(Nc(cc1)cc(Cl)c1F)=O)nc1c2)cc1cc1c2OCCO1, Similarity: 0.19
# SMILES: Cc(cc1)cc(C)c1N1C(SCC(Nc(cccc2)c2C(N)=O)=O)=Nc(cccc2)c2C1=O, Similarity: 0.19
# SMILES: COc1ccc(CN(C(C2CC2)=Nc(cc2)c3cc2NC(c2ccccc2)=O)C3=O)cc1, Similarity: 0.19
# SMILES: CCOc(cc1)ccc1C(NCCNc(c(C#N)cc1c2)nc1cc1c2OCO1)=O, Similarity: 0.19
# SMILES: CCc(cc1cc2C#N)ccc1nc2SCC(NC1CCCC1)=O, Similarity: 0.19
# SMILES: Cc1cc(NC(c(cnn2c(C(F)F)c3)c2nc3-c2ccccc2)=O)no1, Similarity: 0.19
# SMILES: Cc1csc(N=C(N2)SCC(Nc(cccc3)c3Cl)=O)c1C2=O, Similarity: 0.19
# SMILES: CCOc(c(NC(c1ccco1)=O)c1)cc(NS(c(cc2)ccc2OC)(=O)=O)c1OCC, Similarity: 0.19
# SMILES: NC(c1c(NC(CNCc2ccccc2)=O)sc2c1CCCC2)=O, Similarity: 0.19
# SMILES: CCOc(c(NC(c1ccco1)=O)c1)cc(NC(c(cc2)ccc2OC)=O)c1OCC, Similarity: 0.19
# SMILES: Cc1c(C)sc(NC(CSc2nc3ccccc3cc2C)=O)n1, Similarity: 0.19
# SMILES: COc(cccc1)c1NC(C(C(NC1=C2CCCC1)=O)=C2O)=O, Similarity: 0.19
# SMILES: CCOc(c(NC(c1ccco1)=O)c1)cc(NC(c2cccs2)=O)c1OCC, Similarity: 0.19
# SMILES: COc(cccc1)c1NC(Nc1nnc(COc2ccccc2)s1)=O, Similarity: 0.19
# SMILES: Cc1cccc(NC(c2cc(-c3ncccc3)nc3ccccc23)=O)n1, Similarity: 0.19
# SMILES: CC(C)C(Nc(cc1C)cc(-c2nc(cccc3)c3s2)c1O)=O, Similarity: 0.19
# SMILES: O=C(c1ccco1)Nc1ncc(Cc(cc2)cc(Cl)c2Cl)s1, Similarity: 0.19
# SMILES: CCOc(cc(cc1)-c(cc(-c(cc2)ccc2O)nc2N)c2C#N)c1O, Similarity: 0.19
# SMILES: NC(c(cc1)ccc1-c(o1)nnc1SCc(cccc1)c1C#N)=S, Similarity: 0.19
# SMILES: COCCCN1C(SCC(Nc(cccc2)c2Oc2ccccc2)=O)=Nc(sc2c3CCC2)c3C1=O, Similarity: 0.19
# SMILES: CCOC(c1c(N)sc2c1ccc(Br)c2OC)=O, Similarity: 0.19
# SMILES: Cc(cc1)cc(C)c1NC(CS(c(cccc1)c1N)=O)=O, Similarity: 0.19
# SMILES: O=C(C1CC1)Nc1cc2ccccc2nc1C1CCCCC1, Similarity: 0.19
# SMILES: COC(c(cc1)cc(NC(c2ccco2)=O)c1Cl)=O, Similarity: 0.19
# SMILES: CCOC(CN(C(c1ccccc1)=Nc1c2cccc1)C2=O)=O, Similarity: 0.19
# SMILES: CC(C)(C)C(Nc(c(C)c1)cnc1NC(c1ccccc1)=O)=O, Similarity: 0.19
# SMILES: O=C(CS(c1cc2ccccc2cc1)(=O)=O)Nc1ncccc1, Similarity: 0.19
# SMILES: Cn1c(NC(c2ccccc2)=O)ncc1-c(cc1)ccc1Br, Similarity: 0.19
# SMILES: O=C(C1=Cc(cccc2)c2OC1=O)Nc1ccccc1, Similarity: 0.19
# SMILES: Nc1nnc(SCC(c2ccccc2)=O)s1, Similarity: 0.19
# SMILES: Nc1nc(cccc2)c2n1C(Cc1ccccc1)=O, Similarity: 0.19
# SMILES: N#Cc(c(N(CCC1)CCN1C(Nc(cc1)ccc1F)=O)nc1c2)cc1cc1c2OCO1, Similarity: 0.19
# SMILES: N#Cc(c(N(CCC1)CCN1C(Nc(cc1)ccc1Cl)=O)nc1c2)cc1cc1c2OCO1, Similarity: 0.19
# SMILES: CC(C(Nc1cccc2ccccc12)=O)Sc1nc(-c2cnccc2)n[nH]1, Similarity: 0.19
# SMILES: Cc1cc(NC(CSc(c(C#N)cc2c3)nc2cc(OC)c3OC)=O)no1, Similarity: 0.19
# SMILES: COc(cccc1)c1NC(CSc1nnc(NC(c2cccs2)=O)s1)=O, Similarity: 0.19
# SMILES: CCOC(c1c(C)c(C(N(Cc2cccc3ccccc23)C=N2)=O)c2s1)=O, Similarity: 0.19
# SMILES: O=C(c1cccs1)Nc1cc(-c2noc(-c3ccncc3)n2)ccc1, Similarity: 0.19
# SMILES: Cc1cc(NC(CCc(cc2)ccc2OC)=O)nn1Cc1ccccc1, Similarity: 0.19
# SMILES: O=C(COC(c(c(NC(c1ccccc1)=O)ccc1)c1Cl)=O)Nc1ncccn1, Similarity: 0.19
# SMILES: O=C(Nc1nc(SCc(cc2)ccc2F)ns1)Nc(cccc1)c1F, Similarity: 0.19
# SMILES: Nc1nonc1-c1nc(cccc2)c2n1CC(Nc1ccccc1)=O, Similarity: 0.19
# SMILES: COc1cccc(C(Nc(cc2)ncc2NC(c(cccc2)c2OC)=O)=O)c1, Similarity: 0.19
# SMILES: Cc1cccc(NC(c(cc2)cc(CC3)c2N3S(C)(=O)=O)=O)c1C, Similarity: 0.19
# SMILES: COc(cccc1)c1C(Nc1ccc(CC2)c3c2cccc13)=O, Similarity: 0.19
# SMILES: Cc1c(C(OC)=O)sc(NC(COc(cc2)ccc2OC)=O)n1, Similarity: 0.19
# SMILES: COc(cc1)ccc1-c(c(CCCC1)c1nc1N)c1C#N, Similarity: 0.19
# SMILES: O=C1Oc(ccc(Cl)c2)c2C=C1c1nnc(-c(cccc2)c2Br)o1, Similarity: 0.19
# SMILES: CCC(Nc1c(C(N)=O)c(C)c(Cc2ccccc2)s1)=O, Similarity: 0.19
# SMILES: Cc1c(C(Nc2nccs2)=O)oc2c1cccc2, Similarity: 0.19
# SMILES: O=C(Nc1cccc2ccccc12)O/N=C/c(cccc1)c1Cl, Similarity: 0.19
# SMILES: COc(cccc1)c1NC(c1ccc(-c(cccc2)c2Cl)o1)=O, Similarity: 0.19
# SMILES: CCCC(Nc1nc(ccc(NC(C)=O)c2)c2s1)=O, Similarity: 0.19
# SMILES: O=C(CN(C(Cc1ccccc1)=Nc1c2cccc1)C2=O)NCc1ccccc1, Similarity: 0.19
# SMILES: OC(CCCC(Nc(cccc1)c1-n1cncc1)=O)=O, Similarity: 0.19
# SMILES: CC(NC(Cc1ccccc1)C(NC(CC1)CCN1c1nc(C)cc(C)c1C#N)=O)=O, Similarity: 0.19
# SMILES: COc(ccc(C(NCCCNc(c(C#N)cc1c2)nc1cc1c2OCO1)=O)c1)c1OC, Similarity: 0.19
# SMILES: Oc1cc2ccccc2cc1C(Nc1cccc(Cl)c1)=O, Similarity: 0.19
# SMILES: O=C(Nc(cccc1)c1OC(N1CCCCC1)=O)N1CCCCC1, Similarity: 0.19
# SMILES: O=C(NCc1ccncc1)Nc(cccc1)c1Cl, Similarity: 0.19
# SMILES: CCOc(cccc1)c1Nc1nc(-c(cc2)cc(OC)c2OC)c(CC(O)=O)s1, Similarity: 0.19
# SMILES: COCCNC(c1nn2c(C(F)(F)F)cc(-c3ccccc3)nc2c1Br)=O, Similarity: 0.19
# SMILES: Cc(cccc1)c1NC(CSc1nc(C2CC2)nc2ccccc12)=O, Similarity: 0.19
# SMILES: COc(cc1)cc(NC(c2cc(NC(c3ccco3)=O)ccc2)=O)c1OC, Similarity: 0.19
# SMILES: Cc1c(Cc2ccccc2)sc(/N=C/c(s2)ccc2Br)c1C(N)=O, Similarity: 0.19
# SMILES: O=C(c1c(NC(c(cccc2)c2Cl)=O)sc2c1CCCC2)N1CCCCC1, Similarity: 0.19
# SMILES: COC(c(cc1OCCOc1c1)c1NC(C1=Cc(cccc2)c2OC1=O)=O)=O, Similarity: 0.19
# SMILES: O=C(C1=Cc(cccc2)c2OC1=O)Nc1nc(-c2cccs2)cs1, Similarity: 0.19
# SMILES: Cc(c(C)c1C#N)c(C)nc1SCC(c(cc1)ccc1Br)=O, Similarity: 0.19
# SMILES: CCn1c(ccc(C(Nc2ccccc2)=O)c2)c2nc1C, Similarity: 0.19
# SMILES: O=C(c(cc1)ccc1S(N1CCOCC1)(=O)=O)Nc(cccc1)c1Cl, Similarity: 0.19
# SMILES: O=C(c(cc1)cnc1Nc(cccc1)c1Cl)NCc1ccccc1, Similarity: 0.19
# SMILES: COc1cc2ccccc2cc1C(Nc(cc1)ncc1Cl)=O, Similarity: 0.19
# SMILES: Nc(nc(CCCCC1)c1c1-c2cnccc2)c1C#N, Similarity: 0.19
# SMILES: Cc(cccc1)c1C(Nc1c(C(NC)=O)c(CCCC2)c2s1)=O, Similarity: 0.19
# SMILES: Cc1cc2nc(C(NCc3ccccc3)=O)cn2cc1, Similarity: 0.19
# SMILES: O=C(c1ccccc1)Nc(cccc1)c1C(N/N=C/c1ccco1)=O, Similarity: 0.19
# SMILES: Nc(c(C#N)c1-c(cc2)ccc2F)nc(NC(N2)=O)c1C2=O, Similarity: 0.19
# SMILES: Nc(cc1)cc2c1N=C(C1CC1)N(Cc1ccccc1)C2=O, Similarity: 0.19
# SMILES: CCn(c(CNC(c1ccncc1)=O)c1)c2c1cccc2, Similarity: 0.19
# SMILES: Cc1cc(C(Nc(cc2)cc(C)c2NC(c2ccco2)=O)=O)cc(C)c1, Similarity: 0.19
# SMILES: Nc1nc(SCC(Nc2cc(C(F)(F)F)ccc2)=O)nc(N)c1, Similarity: 0.19
# SMILES: Cc1cc(C(F)(F)F)c(c(N)nn2C(Cc3c[nH]c4c3cccc4)=O)c2n1, Similarity: 0.19
# SMILES: COc(ccc(-c1nc(nccc2)c2o1)c1)c1NC(c(cccc1)c1F)=O, Similarity: 0.19
# SMILES: CC(N(Cc(cc1)ccc1F)C(c1c2)=O)=Nc1cc(Cl)c2NC(c1ccncc1)=O, Similarity: 0.19
# SMILES: CCOc(ccc(-c(c(C(N(C)C(N1C)=O)=O)c1nc1N)c1C#N)c1)c1OC, Similarity: 0.19
# SMILES: Cc(nc1SCC(Nc(ccc(F)c2)c2F)=O)cc(COC)c1C#N, Similarity: 0.19
# SMILES: O=C(CSc1nnc(-c(cccc2)c2NC(c2ccccc2)=O)o1)OC1CCCCC1, Similarity: 0.19
# SMILES: Cc1cccc(C(Nc(cc2)ccc2S(N)(=O)=O)=O)c1, Similarity: 0.19
# SMILES: Cc1c(C)sc(NC(c(cc2)ccc2Br)=O)c1C(O)=O, Similarity: 0.19
# SMILES: Nc1nnc(SCC(n2c(cccc3)c3c3c2CCCC3)=O)s1, Similarity: 0.19
# SMILES: Cc1cccc(NC(C(Cc(cc2)cc(OC)c2OC)C#N)=O)n1, Similarity: 0.19
# SMILES: CCOc1ccc(cc(c(SCC(OC(C)C)=O)n2)C#N)c2c1, Similarity: 0.19
# SMILES: O=C(Cn1nnc(-c(cccc2)c2NC(c(cc2)ccc2Cl)=O)n1)Nc1ccccc1, Similarity: 0.19
# SMILES: O=C(C(CCC1)CN1C(NCc1ccccc1)=O)Nc1cccc2ccccc12, Similarity: 0.19
# SMILES: Oc1c(cc(cc2)F)c2ncc1NC(NCCCc1ccccc1)=O, Similarity: 0.19
# SMILES: O=C(c1ccc(CSc2nc(cccc3)c3s2)cc1)Nc1nccs1, Similarity: 0.19
# SMILES: CCNC(NCCNc(c(C#N)cc1c2)nc1ccc2OC)=S, Similarity: 0.19
# SMILES: Nc(cc1)ccc1C(Nc(cc1)cc2c1[nH]c(-c1cnccc1)n2)=O, Similarity: 0.19
# SMILES: Cc1c(C(Nc(cc2)ccc2S(Nc2nc(C)cc(C)n2)(=O)=O)=O)oc2c1cccc2, Similarity: 0.19
# SMILES: CCC(Nc1nc(ccc(NC(c2cnccc2)=O)c2)c2s1)=O, Similarity: 0.19
# SMILES: O=C(c(cc1)ccc1Cl)Nc1ncc(Cc(cccc2)c2Cl)s1, Similarity: 0.18
# SMILES: COC(c(cc1OCOc1c1)c1NC(c1cccs1)=O)=O, Similarity: 0.18
# SMILES: Cc1cccc(-c2n[nH]c(NC(c(cc3)ccc3Br)=O)c2)c1, Similarity: 0.18
# SMILES: COc(ccc(CC(C(Nc1ccccc1)=O)C#N)c1)c1OC, Similarity: 0.18
# SMILES: CCOC(C(C(C)=C1C#N)=NN(c2ccccc2)C1=O)=O, Similarity: 0.18
# SMILES: CCN(C1CCCCC1)C(c1c(C)c(C#N)c(N)s1)=O, Similarity: 0.18
# SMILES: CCc1nnc(NC(Nc2cc(OC)ccc2)=O)s1, Similarity: 0.18
# SMILES: CC(Nc1nc(ccc(NC(c(cc2)ccc2Cl)=O)c2)c2s1)=O, Similarity: 0.18
# SMILES: CC(Nc1nnc(SCC(NCc2ccccc2)=O)s1)=O, Similarity: 0.18
# SMILES: CC(Nc(n1nc2)c2C#N)=C(Cc2ccccc2)C1=O, Similarity: 0.18
# SMILES: CCc1cc2c(NCCCC(O)=O)nc(C)nc2s1, Similarity: 0.18
# SMILES: CC(C)c(cc1)ccc1NC(c(snc12)c2nc(C)nc1O)=O, Similarity: 0.18
# SMILES: O=C(C1=Cc(cccc2)c2OC1=O)Nc(cc1)ncc1Cl, Similarity: 0.18
# SMILES: Cc(ccc(NC(Cn1c(-c2nonc2N)nc2c1cccc2)=O)c1)c1F, Similarity: 0.18
# SMILES: N#Cc1c(SCC(Nc(ccc(F)c2)c2F)=O)sc(C(O)=C2)c1NC2=O, Similarity: 0.18
# SMILES: Cc1cc(NC(c(cc2)cc3c2OCCO3)=O)cc(-c2nc(cccc3)c3s2)c1O, Similarity: 0.18
# SMILES: COC(C1(Cc(cccc2)c2Br)CCOCC1)=O, Similarity: 0.18
# SMILES: O=C(c1cccs1)Nc1cc(-c2noc(-c3cnccc3)n2)ccc1, Similarity: 0.18
# SMILES: CCOc(cc(cc1)-c(c(CCCC2)c2nc2N)c2C#N)c1O, Similarity: 0.18
# SMILES: O=C1NC(CN(Cc2ccccc2)C(Nc(cccc2)c2Cl)=S)=Nc2c1cccc2, Similarity: 0.18
# SMILES: CCOC(c1c(C)nc(NC(COc2cccc(Cl)c2)=O)s1)=O, Similarity: 0.18
# SMILES: CCN1C(SCC(Nc2c(C)cc(C)cc2C)=O)=Nc(cccc2)c2C1=O, Similarity: 0.18
# SMILES: O=C1Oc(ccc(Br)c2)c2C=C1c1csc(Nc(cccc2)c2F)n1, Similarity: 0.18
# SMILES: O=C(c1cccs1)Nc1cc(-c2noc(-c3ncccc3)n2)ccc1, Similarity: 0.18
# SMILES: COc(cccc1)c1NC(Cn1nnc(-c(cccc2)c2NC(c2ccccc2)=O)n1)=O, Similarity: 0.18
# SMILES: N#Cc(c(SCC(c(cc1)ccc1Cl)=O)nc1c2)cc1cc1c2OCCO1, Similarity: 0.18
# SMILES: CCOc(c(NC(Cc(cccc1)c1OC)=O)c1)cc(NC(c2cccs2)=O)c1OCC, Similarity: 0.18
# SMILES: CCOC(Cc1csc(NC(NC(c2c(C)cccc2)=O)=S)n1)=O, Similarity: 0.18
# SMILES: O=C(c1ccco1)Nc(cc1)ccc1C(O1)=Nc(ccc(Cl)c2)c2C1=O, Similarity: 0.18
# SMILES: CCOC(C(CC(Nc1nc(C(C)=O)c(C)s1)=O)C(C)c1ccccc1)=O, Similarity: 0.18
# SMILES: CCOc(cccc1)c1N(C(c(cccc1)c1Br)=O)C1=NCCCS1, Similarity: 0.18
# SMILES: COc(cc1)ccc1-c1noc(CCC(Nc(cccc2)c2Cl)=O)n1, Similarity: 0.18
# SMILES: Cc1c(C)sc(N=C(N2CCOC)SCC(Nc(ccc(OC)c3)c3OC)=O)c1C2=O, Similarity: 0.18
# SMILES: Cc(cc1)ccc1S(/N=C(\N)/Nc1nc(cccc2)c2o1)(=O)=O, Similarity: 0.18
# SMILES: Cc(cc1)ccc1S(N(CC1)CCC1C(Nc(ccc(C)c1)c1Br)=O)(=O)=O, Similarity: 0.18
# SMILES: CCOCCCN1C(SCC(Nc2c(C(N)=O)c(CCC3)c3s2)=O)=Nc(cccc2)c2C1=O, Similarity: 0.18
# SMILES: COc(c1ccccc1cc1)c1C(Nc(cc1)ncc1Cl)=O, Similarity: 0.18
# SMILES: CC(C(Nc1cc(N)ccc1)=O)n1nnc2c1cccc2, Similarity: 0.18
# SMILES: COc(cc1)ccc1C(Nc1cc(OC(c2ccco2)=O)ccc1)=O, Similarity: 0.18
# SMILES: COc1cccc(C(Nc(cc2)ccc2-c2nn(CC(NCc3ccccc3)=O)nn2)=O)c1, Similarity: 0.18
# SMILES: COC(c1c(NC(c(cccc2)c2C(O)=O)=O)sc2c1CCCC2)=O, Similarity: 0.18
# SMILES: Cc(cc1)cc2c1n(C1CCN(CC(Nc3cccc4ccccc34)=O)CC1)nn2, Similarity: 0.18
# SMILES: Nc1nonc1-c1nc(cccc2)c2n1CC(Nc1cc(CCC2)c2cc1)=O, Similarity: 0.18
# SMILES: CCCc1nnc(NC(C(CC)OC(c2cc(C)nc3ccccc23)=O)=O)s1, Similarity: 0.18
# SMILES: O=C(c1nc2ccccc2cc1)Nc(cc1)cc(CO2)c1C2=O, Similarity: 0.18
# SMILES: COc1cc2cc(C#N)c(N(CC3)CCC3O)nc2cc1, Similarity: 0.18
# SMILES: CC(C)C(Nc(cc1)cc(OC)c1NC(c1ccco1)=O)=O, Similarity: 0.18
# SMILES: Cc1csc(NC(CS(c2cc3ccccc3cc2)(=O)=O)=O)n1, Similarity: 0.18
# SMILES: COC(c(cc(cc1)NC(c2cc(cccc3)c3o2)=O)c1Cl)=O, Similarity: 0.18
# SMILES: Cc1cc(NC(CCC(N(CC(NC2CCCCC2)=O)Cc2ccccc2)=O)=O)ncc1, Similarity: 0.18
# SMILES: CC(Nc1cc(NC(CSc2nc(N)cc(N)n2)=O)c(C)cc1)=O, Similarity: 0.18
# SMILES: COc(cc1)cc2c1nc(NC(CSc1ncnc3c1c(-c1ccccc1)cs3)=O)s2, Similarity: 0.18
# SMILES: Cc1ccc(cc(c(SCC(N2CCOCC2)=O)n2)C#N)c2c1C, Similarity: 0.18
# SMILES: CCOc(cccc1)c1C(Nc1nc(CC(C)(C)CC2=O)c2s1)=O, Similarity: 0.18
# SMILES: COc(ccc(Br)c1/C=N/c2cc(NC(c3ccccc3)=O)ccc2)c1O, Similarity: 0.18
# SMILES: Cc(cccc1)c1-c1nc(-c2cccc(NC(c3cccs3)=O)c2)no1, Similarity: 0.18
# SMILES: CC(Nc(cc1)ccc1S(N(CC1)CCC1c1nc(cccc2)c2s1)(=O)=O)=O, Similarity: 0.18
# SMILES: CCC(Nc(cc1)cc2c1N=C(C)N(Cc(cccc1)c1Cl)C2=O)=O, Similarity: 0.18
# SMILES: CC(C)(Cc1c23)OCc1c(N1CCOCC1)nc2sc(C(O)=O)c3N, Similarity: 0.18
# SMILES: O=C(C(CC1)CCN1C(c([nH]nc1)c1Br)=O)c1nc(cccc2)c2s1, Similarity: 0.18
# SMILES: O=C(NCc1nc(-c2cnccc2)n[nH]1)Nc1c(C(F)(F)F)cccc1, Similarity: 0.18
# SMILES: CCN(CC)C(c(sc1nc(N2CCOCC2)c(CCCC2)c2c11)c1N)=O, Similarity: 0.18
# SMILES: CCC(C)OC(C(C)N(C=Nc1c2cc(-c3ccccc3)s1)C2=O)=O, Similarity: 0.18
# SMILES: CCc1cc(C(c(cccc2)c2OC)=O)c(N)s1, Similarity: 0.18
# SMILES: Cc(cccc1cc2C#N)c1nc2N1CCCCC1, Similarity: 0.18
# SMILES: Oc(cc1)cc(O2)c1C=C(C(Nc1ccccc1)=O)C2=O, Similarity: 0.18
# SMILES: COc(cc1)ccc1-c1c(CC(O)=O)sc(N)n1, Similarity: 0.18
# SMILES: Cc1c(C)sc(NC(CSc2nncn2-c2cnccc2)=O)c1C#N, Similarity: 0.18
# SMILES: CC(C(NCc(cc1)ccc1F)=O)N(C(c(snc1C(N)=O)c1N)=O)c(cccc1)c1F, Similarity: 0.18
# SMILES: COc(cc1)cc(C=C2C(NCc3ccccc3)=O)c1OC2=O, Similarity: 0.18
# SMILES: Oc1c2nc(/C=N/NC(c3cccc(Br)c3)=O)ccc2ccc1, Similarity: 0.18
# SMILES: COc(cccc1)c1NC(c1ccc(CN2CCOCC2)cc1)=O, Similarity: 0.18
# SMILES: CCC(Nc1nnc(Cc2c[nH]c3c2cccc3)s1)=O, Similarity: 0.18
# SMILES: Cc1c(C(NC(Nc2nc(C)ccc2)=S)=O)oc2c1cccc2, Similarity: 0.18
# SMILES: CCOC(C(C(C)=C1C#N)=NN(c2c(C)cccc2)C1=O)=O, Similarity: 0.18
# SMILES: N#CC(C(c(ccc(Cl)c1)c1Cl)=O)c1nc(cccc2)c2[nH]1, Similarity: 0.18
# SMILES: Nc(cc1)ccc1C(Nc(cc1)cc2c1[nH]c(-c1ccncc1)n2)=O, Similarity: 0.18
# SMILES: Cn(c(C(Nc(cc(cc1)OC)c1OC)=O)c1)c2c1scc2, Similarity: 0.18
# SMILES: CCn(c(CNC(c1cnccc1)=O)c1)c2c1cccc2, Similarity: 0.18
# SMILES: CC(CC1C(O)=O)=CCC1C(Nc1nc(cccc2)c2s1)=O, Similarity: 0.18
# SMILES: COCCN1C(SCC(Nc(sc2c3CCCC2)c3C#N)=O)=Nc(sc2c3CCC2)c3C1=O, Similarity: 0.18
# SMILES: CC(C)(C)NC(C(c1c[nH]c2c1cccc2)N(CCc1ccccc1)C(c(snc1C(N)=O)c1N)=O)=O, Similarity: 0.18
# SMILES: Cc(cc1cc2C#N)c(C)cc1nc2SCC(c(cc1)cc2c1OCCO2)=O, Similarity: 0.18
# SMILES: Cc1ccc(cc(c(SCC(c(cc2)cc(OC)c2OC)=O)n2)C#N)c2c1C, Similarity: 0.18
# SMILES: CCN1C(SCC(Nc2cccc(Cl)c2C)=O)=Nc(cccc2)c2C1=O, Similarity: 0.18
# SMILES: CCOC(c1c(NC(COc(ccc(C)c2)c2Br)=O)sc(C(C)=O)c1C)=O, Similarity: 0.18
# SMILES: COc(cc1)ccc1NC(CSc1nnc(-c2cccc(Br)c2)o1)=O, Similarity: 0.18
# SMILES: CCCC(Nc(cc1)cc2c1N=C(C)N(Cc(cccc1)c1Cl)C2=O)=O, Similarity: 0.18
# SMILES: CCc(cc1cc2C#N)ccc1nc2SCC(N1CCOCC1)=O, Similarity: 0.18
# SMILES: CCOc(c(NC(CCC(N1CCCC1)=O)=O)c1)cc(NC(c2cccs2)=O)c1OCC, Similarity: 0.18
# SMILES: CC(C)n1c(N(CC2)CCN2C(Nc(ccc(F)c2)c2F)=O)nc2c1cccc2, Similarity: 0.18
# SMILES: O=C(c1cnccc1)Nc(cc(cc1)-c2nc(cc(cc3)Cl)c3o2)c1Cl, Similarity: 0.18
# SMILES: Cc1csc(NC(CSc2nc(C)cc(COC)c2C#N)=O)n1, Similarity: 0.18
# SMILES: CCOC(CSc1nc(C)cc(C)c1C#N)=O, Similarity: 0.18
# SMILES: Cc1cccc(NC(CS(CC(Nc(cccc2)c2-c2ccccc2)=O)=O)=O)c1C, Similarity: 0.18
# SMILES: O=C(c1ccco1)Nc(cc1)cc(C=C2)c1OC2=O, Similarity: 0.18
# SMILES: N#Cc(c(N(CCC1)CCN1C(c1cccc(F)c1)=O)nc1c2)cc1cc1c2OCO1, Similarity: 0.18
# SMILES: O=C(CN(CC1)CCN1c1nc(-c(cc2)ccc2F)cs1)Nc(cccc1)c1N1CCOCC1, Similarity: 0.18
# SMILES: Cc1cccc(NC(CC(C(N2C)=O)S/C2=N/c2nc(cccc3)c3s2)=O)c1C, Similarity: 0.18
# SMILES: Oc(cccc1)c1-c(o1)nnc1SCC(Nc(cc1)ccc1Br)=O, Similarity: 0.18
# SMILES: O=C(CCCCCN(C(c1c2cccc1)=O)C2=O)Nc1nc(cccc2)c2s1, Similarity: 0.18
# SMILES: Cc1ccc(cc(c(NCCNC(NC)=S)n2)C#N)c2c1C, Similarity: 0.18
# SMILES: CC(CCC1)c(nc2N)c1c(-c1ccco1)c2C#N, Similarity: 0.18
# SMILES: Cc1cccc(CC(C(Nc2ccccc2)=O)c2nnn[nH]2)c1, Similarity: 0.18
# SMILES: O=C(c1cccs1)Nc1cccc(-c2noc(-c3cccs3)n2)c1, Similarity: 0.18
# SMILES: NC(c1nn2c(C(F)(F)F)cc(-c(cc3)ccc3Br)nc2c1Cl)=O, Similarity: 0.18
# SMILES: Oc(c(c(nc1)c2)cc3c2OCCO3)c1C(NCc1ccccc1)=O, Similarity: 0.18
# SMILES: O=C(c1c(-c2cc3ccccc3cc2)ocn1)Nc1cnccc1, Similarity: 0.18
# SMILES: O=C(CSc1nnc(-c2cocc2)c(-c2cocc2)n1)c(s1)ccc1Br, Similarity: 0.18
# SMILES: Cc1ccc(C(C(NCc2ccccc2)=O)N(C(c(snc2C(N)=O)c2N)=O)c2c(C)cc(C)cc2)o1, Similarity: 0.18
# SMILES: Cc1c(C(Nc(cc2)ccc2S(Nc2nc(C)nc(C)c2)(=O)=O)=O)oc2c1cccc2, Similarity: 0.18
# SMILES: CCOC(c1c(NC(c(cc(cc2)Br)c2Cl)=O)sc2c1CCCC2)=O, Similarity: 0.18
# SMILES: CCOC(c1c(NC(c2ccco2)=O)sc(C(Nc(cc2)ccc2OC)=O)c1C)=O, Similarity: 0.18
# SMILES: Cc(occ1)c1-c(n1C)nnc1SCC(Nc(ccc(C)c1)c1Br)=O, Similarity: 0.18
# SMILES: NS(c(cc1)ccc1NC(c(c(Cl)ccc1)c1Cl)=O)(=O)=O, Similarity: 0.18
# SMILES: N#Cc1ccc(C2N(Cc3ccccc3)CCN2Cc2ccccc2)cc1, Similarity: 0.18
# SMILES: CCn1c(N(CC2)CCN2C(Nc(ccc(F)c2)c2F)=O)nc2c1cccc2, Similarity: 0.18
# SMILES: CC(C)(C(Nc1noc(C)c1)=O)Sc1nc(-c2ccccc2)nc2ccc(C)cc12, Similarity: 0.18
# SMILES: Cc1ccc(cc(c(N(CCC2)CCN2C(C2CCCCC2)=O)n2)C#N)c2c1, Similarity: 0.18
# SMILES: CN(CCc1ccccc1)S(c1csc(C(Nc2nncs2)=O)c1)(=O)=O, Similarity: 0.18
# SMILES: CC(C)(C)c(cc1)cc(NC(c2c(-c(cccc3)c3Cl)ocn2)=O)c1OC, Similarity: 0.18
# SMILES: CCOc1cccc(C(Nc2nc(-c(cc3)cc(OC)c3OC)cs2)=O)c1, Similarity: 0.18
# SMILES: Cc(ccc(-n1nnc(C(NCc2cccs2)=O)c1N)c1)c1F, Similarity: 0.18
# SMILES: CC(N(C)N(C1=O)c2ccccc2)=C1NC(C1=Cc(cc(cc2)Br)c2OC1=O)=O, Similarity: 0.18
# SMILES: CCN(C(CSc1nc(C)cc(COC)c1C#N)=O)c1ccccc1, Similarity: 0.18
# SMILES: O=C(c(cc1)ccc1Br)Nc(cc1)ncc1Cl, Similarity: 0.18
# SMILES: CC(c1cccc(NC(c(cc2)ccc2-c2ccccc2)=O)c1)=O, Similarity: 0.18
# SMILES: CC(C(C#N)=C(N1)SCC(Nc2cc(C(F)(F)F)ccc2)=O)=CC1=O, Similarity: 0.18
# SMILES: COc(cc1)cc(/N=C2\Oc(cc(cc3)O)c3C=C2C(Nc2ncccc2)=O)c1OC, Similarity: 0.18
# SMILES: CC(C)CC(C(NC1CCCCC1)=O)N(Cc1ccccc1)C(c(snc1C(N)=O)c1N)=O, Similarity: 0.18
# SMILES: CCN1C(SCC(Nc(sc2c3CCCC2)c3C#N)=O)=Nc(sc2c3CCC2)c3C1=O, Similarity: 0.18
# SMILES: Cc(cc(cc1)Br)c1NC(CSc1nnc(CNC(c2ccco2)=O)n1C)=O, Similarity: 0.18
# SMILES: CCCCN(CCCC)C(Nc1nc(cccc2)c2[nH]1)=O, Similarity: 0.18
# SMILES: O=C(c(o1)ccc1Br)Nc1cc(NC(c2cc(Cl)ccc2)=O)ccc1, Similarity: 0.18
# SMILES: Cc1ccc(cc(c(NC2CCCCC2)n2)C#N)c2c1, Similarity: 0.18
# SMILES: CCc(cccc1)c1NC(Cn1nnc2c1cccc2)=O, Similarity: 0.18
# SMILES: Cc1n[nH]c(C(N/N=C/c(cc2)ccc2Br)=O)c1, Similarity: 0.18
# SMILES: Cn1nc(C(N/N=C/c2ccccc2)=O)c(I)c1, Similarity: 0.18
# SMILES: COc1cc2cc(C#N)c(N3CCCCC3)nc2cc1, Similarity: 0.18
# SMILES: COc1cc(C(NCCCNC(c2ccco2)=O)=O)cc(OC)c1, Similarity: 0.18
# SMILES: O=C(c([nH]nc1)c1Br)N/N=C/c(cc1)ccc1Cl, Similarity: 0.18
# SMILES: O=C(CNCCN1CCCCC1)Nc(cccc1)c1N1CCCCCC1, Similarity: 0.18
# SMILES: O=C(c1cccs1)Nc(cc1)cc(C=C2)c1OC2=O, Similarity: 0.18
# SMILES: Nc1c(C(N(C(C(NCc2ccccc2)=O)c2cccs2)c2ccccc2)=O)snc1C(NC1CCCCC1)=O, Similarity: 0.18
# SMILES: Cc1c(C(Nc2ccc(C)cc2)=O)sc(NC(c2cccs2)=O)c1C(OC)=O, Similarity: 0.17
# SMILES: CCC(Nc1cccc(NC(CSc2nc(CC)nc3ccccc23)=O)c1)=O, Similarity: 0.17
# SMILES: O=C(c(cc1)ccc1F)Nc1cc(-c2cn(cccc3)c3n2)ccc1, Similarity: 0.17
# SMILES: OC(c1nn2c(C(F)(F)F)cc(-c3cccs3)nc2c1Br)=O, Similarity: 0.17
# SMILES: O=C(c1c(NC(c2ccco2)=O)sc2c1CCCC2)c(cc1)ccc1Cl, Similarity: 0.17
# SMILES: Cc(cc1)ccc1N(c(cc1)c(c2ccc3)c3c1NC(c1ccccc1)=O)C2=O, Similarity: 0.17
# SMILES: CCSc1nsc(NC(Nc2cc(OC)ccc2)=O)n1, Similarity: 0.17
# SMILES: COc(cc1)ccc1-c(nc1SCc2ncccc2)ccc1C#N, Similarity: 0.17
# SMILES: COCCNC(c1cn(Cc2cccc3ccccc23)nn1)=O, Similarity: 0.17
# SMILES: CC(N(CC1)CCN1c(cccc1)c1NC(COc1cc(C)cc(C)c1)=O)=O, Similarity: 0.17
# SMILES: O=C(c1ccco1)Nc1nnc(COc(cc2)ccc2Cl)s1, Similarity: 0.17
# SMILES: N#Cc(c(SCc1cnccc1)nc1c2)cc1cc1c2OCCO1, Similarity: 0.17
# SMILES: Cc(cc1)cc(Cl)c1C(Nc1c(C(N)=O)c(CCCC2)c2s1)=O, Similarity: 0.17
# SMILES: COc(ccc(NC(c1ccco1)=O)c1)c1NC(c(cc1)ccc1F)=O, Similarity: 0.17
# SMILES: Nc(nc(cc1-c(cc2)cc3c2OCO3)-c(ccc(Cl)c2)c2Cl)c1C#N, Similarity: 0.17
# SMILES: O=C(CSC(N1Cc2ccccc2)=Nc(sc2c3CCCC2)c3C1=O)c1ccccc1, Similarity: 0.17
# SMILES: O=C(C(CC1)CCN1S(c(cc1)ccc1Cl)(=O)=O)Nc1nnc(Cc2ccccc2)s1, Similarity: 0.17
# SMILES: O=C(CCC(N(CC(NCc1ccccc1)=O)Cc1ccco1)=O)Nc1ncccc1, Similarity: 0.17
# SMILES: Cc1cc(-c2csc(NC(C3OCCc4c3cccc4)=O)n2)c(C)s1, Similarity: 0.17
# SMILES: O=C(c1nn2c(C(F)(F)F)cc(-c3ccco3)nc2c1)NCc1ccccc1, Similarity: 0.17
# SMILES: CCOC(c1c(C)nc(NC(C(C)SC(N2)=NC(N)=CC2=O)=O)s1)=O, Similarity: 0.17
# SMILES: Cc1cc(NC(CSc2c(c(CCCC3)c3s3)c3ncn2)=O)c(C)cc1, Similarity: 0.17
# SMILES: Cc1ccc(cc(c(SCC(c(cc2)cc3c2OCCO3)=O)n2)C#N)c2c1C, Similarity: 0.17
# SMILES: O=C(c(cc1)cc(F)c1F)NN(C(Cc1cccs1)=Nc1c2cccc1)C2=O, Similarity: 0.17
# SMILES: CCc1nc(NCCNC(c2cc(F)ccc2)=O)c(c(C)c(C)s2)c2n1, Similarity: 0.17
# SMILES: COc(ccc(-c1nc(nccc2)c2o1)c1)c1NC(c(cc1)ccc1F)=O, Similarity: 0.17
# SMILES: Cc(cc1)cc2c1OC(C(Nc1ncc(Cc(cc3)ccc3F)s1)=O)=CC2=O, Similarity: 0.17
# SMILES: CCc(cccc1)c1N(CC(C1)C(OCC(Nc2cccc3ccccc23)=O)=O)C1=O, Similarity: 0.17
# SMILES: Oc1cccc(-c(o2)nnc2SCC(Nc2nc(-c3ccccc3)cs2)=O)c1, Similarity: 0.17
# SMILES: CCOc(ccc(S(N1CCN(C)CC1)(=O)=O)c1)c1NC(c(cccc1)c1F)=O, Similarity: 0.17
# SMILES: CC(C)c(cccc1)c1NC(C(C)Oc1ccccc1)=O, Similarity: 0.17
# SMILES: CCOc(cc1)ccc1N(C(C)C(NC1CCCCC1)=O)C(c(snc1C(NC2CCCC2)=O)c1N)=O, Similarity: 0.17
# SMILES: N#CCNC(C1c(cccc2)c2Oc2c1cccc2)=O, Similarity: 0.17
# SMILES: O=C(c1c(C(NCc2ccccc2)=O)nc[nH]1)NCc1ccccc1, Similarity: 0.17
# SMILES: CC(c1cc(Nc2nc(-c3ccccc3)nc3ccccc23)ccc1)=O, Similarity: 0.17
# SMILES: CC(Oc(cc1)cc(N=C(c2ccccc2)O2)c1C2=O)=O, Similarity: 0.17
# SMILES: Cc(cc1)ccc1NC(c(snc12)c2N=CNC1=O)=O, Similarity: 0.17
# SMILES: NC(Cn1c(-c2nonc2N)nc2c1cccc2)=O, Similarity: 0.17
# SMILES: Cc1ccc(cc(c(N(CC2)CCC2O)n2)C#N)c2c1, Similarity: 0.17
# SMILES: O=C(c1cc(scc2)c2n1Cc1ccccc1)NCc1ccccc1, Similarity: 0.17
# SMILES: CN(C)C(Nc(cnc1cc(OC)ccc11)c1O)=O, Similarity: 0.17
# SMILES: CN(CC1)CCN1C(Nc(cnc1ccccc11)c1O)=O, Similarity: 0.17
# SMILES: O=C(c(cc1)ccc1S(NC1CC1)(=O)=O)Nc1ncccc1, Similarity: 0.17
# SMILES: CCNC(c1cc(S(NCc2ccccc2)(=O)=O)cs1)=O, Similarity: 0.17
# SMILES: CCNC(c1cc(S(Nc2ccccc2)(=O)=O)c(C)s1)=O, Similarity: 0.17
# SMILES: Cc1c(C(Nc(cc2)ccc2OC)=O)n(cccc2)c2c1, Similarity: 0.17
# SMILES: N#CC(C(c(cc1)ccc1F)=O)c1nc(cccc2)c2[nH]1, Similarity: 0.17
# SMILES: CC(C)(C)c1csc(NC(CS(c2ccccc2)(=O)=O)=O)n1, Similarity: 0.17
# SMILES: CN(C)CCNC(c1c(NC(c2ccccc2)=O)sc2c1CCCC2)=O, Similarity: 0.17
# SMILES: CS(N(Cc(cc1)ccc1Cl)c(cc1)ccc1C(Nc(cccc1)c1F)=O)(=O)=O, Similarity: 0.17
# SMILES: Cc(cc1)ccc1C(c1c(NC(c2ccco2)=O)sc2c1CCCC2)=O, Similarity: 0.17
# SMILES: COc1cccc(C(NC2CC(CC3)N(Cc4ccccc4)C3C2)=O)c1, Similarity: 0.17
# SMILES: CCc(cccc1C)c1NC(CS(CC(Nc1cccc2cccnc12)=O)=O)=O, Similarity: 0.17
# SMILES: O=C(c1c(-c2cccs2)ocn1)NCc1cccc2ccccc12, Similarity: 0.17
# SMILES: COc(ccc(C(Nc1nc(ccc(F)c2)c2s1)=O)c1)c1Cl, Similarity: 0.17
# SMILES: CC(C)C(Nc1c(C(Nc2cc(C)ccc2)=O)c(CCC2)c2s1)=O, Similarity: 0.17
# SMILES: Cc(cc(cc1)NC(c2ccco2)=O)c1C1=Cc(cccc2)c2OC1=O, Similarity: 0.17
# SMILES: CCOc(cc1)cc2c1nc(NC(c(cc1)ccc1NC(C)=O)=O)s2, Similarity: 0.17
# SMILES: CCCCCCN(c(cccc1)c1C(O)=C1C(Nc2nccc(C)c2)=O)C1=O, Similarity: 0.17
# SMILES: CCn1c(SCC(Nc2cccc3ccccc23)=O)nnc1-c1c(C)occ1, Similarity: 0.17
# SMILES: Cc1cc(N(CC(NCc2ccccc2)=O)C(CCC(Nc2nccs2)=O)=O)cc(C)c1, Similarity: 0.17
# SMILES: Cc(cc1)cc(-n2nnnc2)c1-c1nn(CC(Nc(ccc(C)c2)c2Br)=O)nn1, Similarity: 0.17
# SMILES: COc(cc1)cc(N2)c1C=C(CC(C(Nc(cc1)ccc1F)=O)C#N)C2=O, Similarity: 0.17
# SMILES: CCc1nnc(NC(CSc2nc(SCC(c3ccccc3)=O)nc(C)c2)=O)s1, Similarity: 0.17
# SMILES: CC(C(Nc1c(C)cccc1)=O)Sc1nnc(-c(cccc2)c2O)n1CCc1ccccc1, Similarity: 0.17
# SMILES: Cc1c(-c(cc2)cc(CC3)c2N3C(c(cccc2)c2F)=O)nc(NC)s1, Similarity: 0.17
# SMILES: COc1cc(C(N(Cc2cccs2)CC(N2)=Nc(cccc3)c3C2=O)=O)cc(OC)c1, Similarity: 0.17
# SMILES: Cc1c(C)sc(N=C(N2)SCC(Nc3cc(C(O)=O)ccc3)=O)c1C2=O, Similarity: 0.17
# SMILES: CCCC(/N=C1\SN(c(cc2)ccc2C(N)=O)N=C1C(NCc1ccccc1)=O)=O, Similarity: 0.17
# SMILES: CCCn1c(N(CC2)CCN2C(c(sc2c3cccc2)c3Cl)=O)nc2c1cccc2, Similarity: 0.17
# SMILES: COc(cc1)cc(NC(C(C2C=CC3C2)C3C(NCc2ncccc2)=O)=O)c1OC, Similarity: 0.17
# SMILES: CCOc(cc(cc1)-c(c(CCCC2C)c2nc2N)c2C#N)c1O, Similarity: 0.17
# SMILES: CCOC(c1c(-c2ccccc2)nc(NC(CSc2nnc(C)[nH]2)=O)s1)=O, Similarity: 0.17
# SMILES: CCC(C)(C)NC(C(c1c[nH]c2c1cccc2)N(C(c(snc1C(N)=O)c1N)=O)c1cc(C)ccc1)=O, Similarity: 0.17
# SMILES: Cc(cccc1)c1NCC(CNc1nc(C)cc(C)n1)O, Similarity: 0.17
# SMILES: O=C(c(cccc1)c1F)Nc(cc1)ncc1Cl, Similarity: 0.17
# SMILES: O=C(c(cc1)ccc1Br)Nc(cc1)cc2c1OCCO2, Similarity: 0.17
# SMILES: O=C(Cc1cccc2ccccc12)NCCc1ccccc1, Similarity: 0.17
# SMILES: CCCC(Nc(cc(c(N)c1)OCC)c1OCC)=O, Similarity: 0.17
# SMILES: CCc(c(O)c1)cc(C(Cc2nc(cccc3)c3s2)=O)c1O, Similarity: 0.17
# SMILES: CCOc1cccc(C(Nc(cc2)ncc2Cl)=O)c1, Similarity: 0.17
# SMILES: CCOC(c1cc(c(C)nn2-c3ccccc3)c2s1)=O, Similarity: 0.17
# SMILES: Cc(nc1SCC(N)=O)cc(COC)c1C#N, Similarity: 0.17
# SMILES: CC(C(c1ccccc1)=O)OC(CCC(Nc(cccc1)c1Cl)=O)=O, Similarity: 0.17
# SMILES: Cc1cc(C)nc(Nc2cc(OC)ccc2)c1C(N)=O, Similarity: 0.17
# SMILES: CCOC(c1c(NC(c(cccc2)c2C(O)=O)=O)sc(C)c1C)=O, Similarity: 0.17
# SMILES: Fc(cccc1)c1Nc1c(c(CCC2)c2s2)c2ncn1, Similarity: 0.17
# SMILES: Cn1c(SCC(c2ccccc2)=O)nnc1-c(cccc1)c1Br, Similarity: 0.17
# SMILES: OCCCNC(Nc1cc2nc(-c3ccccc3)c(-c3ccccc3)nc2cc1)=O, Similarity: 0.17
# SMILES: Cc(cc1)ccc1OCC(Nc1cccc2ncccc12)=O, Similarity: 0.17
# SMILES: Cc1cc(NC(C(C2CCC3)C3C2c2ccccc2)=O)c(C)cc1, Similarity: 0.17
# SMILES: CC(Nc(cc1)ccc1S(Nc1cccc2cccnc12)(=O)=O)=O, Similarity: 0.17
# SMILES: O=C(CSc1ccccc1)Nc1cc(NC(c2ccco2)=O)ccc1, Similarity: 0.17
# SMILES: CCn(c(CNC(c(cccc1)c1Cl)=O)c1)c2c1cccc2, Similarity: 0.17
# SMILES: NC(C(C1c2ccccc2)C#N)=NC(N=C(N)N2)=C1C2=O, Similarity: 0.17
# SMILES: CCOC(c1cc(sc(Br)c2)c2n1CC#N)=O, Similarity: 0.17
# SMILES: CN(c1c(C(N2C)=O)n(CC(Nc3cc4ccccc4cc3)=O)cn1)C2=O, Similarity: 0.17
# SMILES: Cc(cc(C)nc1SCC(c(cc(cc2)OC)c2OC)=O)c1C#N, Similarity: 0.17
# SMILES: O=C(c1cc(-c(cc2)ccc2Cl)nc2ccccc12)NCc1ccco1, Similarity: 0.17
# SMILES: COc(ccc(NC(c1ccco1)=O)c1)c1NC(c(cc1)cc(Cl)c1Cl)=O, Similarity: 0.17
# SMILES: O=C(c1ccco1)Nc(cc1)cc2c1oc(-c1cnccc1)n2, Similarity: 0.17
# SMILES: COc(ccc(NC(c1ccco1)=O)c1)c1NC(c1cccc(Cl)c1)=O, Similarity: 0.17
# SMILES: N#CC1=CC=C(c2cnccc2)N(CC(c(cc2)ccc2F)=O)C1=O, Similarity: 0.17
# SMILES: O=C(c1c(-c2cc3ccccc3cc2)ocn1)Nc(cc1)cc2c1OCO2, Similarity: 0.17
# SMILES: O=C(c1c(-c2cc3ccccc3cc2)ocn1)Nc(cc1)cc2c1OCCO2, Similarity: 0.17
# SMILES: COc(cc1)ccc1NC(Nc1cc(-c2cn(cccc3)c3n2)ccc1)=O, Similarity: 0.17
# SMILES: O=C(C(C1C=CC2C1)C2C(N1)=Nc(cccc2)c2C1=O)NCc1ccccc1, Similarity: 0.17
# SMILES: Cc(cc1)cc(C)c1C(Nc(cc1)cc(OC)c1NC(c1ccco1)=O)=O, Similarity: 0.17
# SMILES: CCOC(c1c(NC(c(cccc2)c2Cl)=O)sc2c1CCCC2)=O, Similarity: 0.17
# SMILES: CCc(cc1)ccc1C(Nc(cc1)cc(OC)c1NC(c1cccs1)=O)=O, Similarity: 0.17
# SMILES: COc(cc(cc1)NC(c2cccc(Cl)c2)=O)c1NC(c1ccco1)=O, Similarity: 0.17
# SMILES: Cc1c(-c(cc2)cc(CC3)c2N3S(c2ccccc2)(=O)=O)nc(N)s1, Similarity: 0.17
# SMILES: Cc1cccc(N(CC(NCCc2ccccc2)=O)C(CCC(Nc2ncccc2)=O)=O)c1, Similarity: 0.17
# SMILES: CC(NC(Cc1ccccc1)C(NC(CC1)CCN1C(Nc(cc1)ccc1C#N)=O)=O)=O, Similarity: 0.17
# SMILES: COc(ccc(-c1nc(nccc2)c2o1)c1)c1NC(c1cccc(F)c1)=O, Similarity: 0.17
# SMILES: CCc1nnc(NC(CSC(N2CCc3ccccc3)=Nc(sc(C)c3C)c3C2=O)=O)s1, Similarity: 0.17
# SMILES: O=C(Nc(cccc1)c1F)N(Cc1cnccc1)CC1=Cc(cc2OCCOc2c2)c2NC1=O, Similarity: 0.17
# SMILES: COc(c(OC)c1)cc(C=C2CN(Cc3cnccc3)C(Nc(cccc3)c3F)=O)c1NC2=O, Similarity: 0.17
# SMILES: Nc1nnc(-c(cccc2)c2-c2nnc(N)s2)s1, Similarity: 0.17
# SMILES: OC(C(C(Nc1ccccc1)=O)O)C(Nc1ccccc1)=O, Similarity: 0.17
# SMILES: O=C(COc1ccccc1)Nc(cc(cc1)Cl)c1Cl, Similarity: 0.17
# SMILES: O=C(Nc(cccc1)c1Cl)N(CC1)c2c1cccc2, Similarity: 0.17
# SMILES: CN1CCN(CC(Nc(cccc2)c2F)=O)CC1, Similarity: 0.17
# SMILES: CS(CCNC(Nc(cc1)ccc1C#N)=O)=O, Similarity: 0.17
# SMILES: CCCCCC(c1ccccc1)NNC(c1cccc(Br)c1)=O, Similarity: 0.17
# SMILES: CC(Oc(cc1)ccc1C(O1)=Nc(ccc(Br)c2)c2C1=O)=O, Similarity: 0.17
# SMILES: CC(CC1)CCN1c(nc(ccc(OC)c1)c1c1)c1C#N, Similarity: 0.17
# SMILES: O=C(c1cc(-c(cc2)ccc2F)n[nH]1)N/N=C/c1ccccc1, Similarity: 0.17
# SMILES: O=C(C1(CCCCC1)NC(c1nc2ccccc2cc1)=O)Nc1ccccc1, Similarity: 0.17
# SMILES: NC(Cc1nc(C2=Cc(cccc3)c3OC2=O)cs1)=O, Similarity: 0.17
# SMILES: O=C(c1cn(Cc2ccccc2)nn1)NCc1cnccc1, Similarity: 0.17
# SMILES: COc(ccc(C(Nc(cc1)cc2c1OCCO2)=O)c1)c1Br, Similarity: 0.17
# SMILES: CN(C(c1ccccc1)=O)c1nc(CC(Nc2ccccc2)=O)cs1, Similarity: 0.17
# SMILES: Cc(cccc1)c1-c1nc(cc(cc2)NC(c(cccc3)c3OC)=O)c2o1, Similarity: 0.17
# SMILES: O=C(c1cc(-c(s2)ccc2Cl)n[nH]1)N/N=C/c1cnccc1, Similarity: 0.17
# SMILES: Cc1cc(NC(Cc2noc(-c3cnccc3)n2)=O)c(C)cc1, Similarity: 0.17
# SMILES: COc(cc1)ccc1-c1nc(cc(cc2)NC(c(o3)ccc3I)=O)c2o1, Similarity: 0.17
# SMILES: O=C(CSc1nnc(NC(c2ccco2)=O)s1)Nc(cc1)ccc1Cl, Similarity: 0.17
# SMILES: CC(C)c1nc2ccccc2c(SCC(Nc2cc(F)ccc2)=O)n1, Similarity: 0.17
# SMILES: COc1cccc(NC(Nc2nnc(COc(cc3)ccc3F)s2)=O)c1, Similarity: 0.17
# SMILES: O=C(c1nccc2ccccc12)NN(CC(N1CCc2ccccc2)=O)C1=O, Similarity: 0.17
# SMILES: O=C(CN(CC1)CCC1c1nc(cccc2)c2[nH]1)Nc(cccc1)c1Cl, Similarity: 0.17
# SMILES: O=C(COc1nc(cccc2)c2s1)n1c(cccc2)c2c2c1CCCC2, Similarity: 0.17
# SMILES: COc(ccc(NC(c1ccco1)=O)c1)c1NC(c(ccc(Cl)c1)c1Cl)=O, Similarity: 0.17
# SMILES: COc(ccc(NC(c1ccco1)=O)c1)c1NC(c(cc(cc1)Cl)c1Cl)=O, Similarity: 0.17
# SMILES: O=C(c1cc2ccccc2cc1)Nc(cc1)cc2c1oc(-c1cnccc1)n2, Similarity: 0.17
# SMILES: COc(cccc1)c1C(Nc(cc1)cc2c1oc(-c(cc1)ccc1F)n2)=O, Similarity: 0.17
# SMILES: N#Cc1c(CN2N=C(c3cccc4ncccc34)OC2=O)cccc1, Similarity: 0.17
# SMILES: Cc(cc1)c(C)cc1N(CC(NCc1ccccc1)=O)C(CCC(Nc1nccs1)=O)=O, Similarity: 0.17
# SMILES: N#Cc(c(N(CCC1)CCN1C(NC1CCCCC1)=O)nc1c2)cc1cc1c2OCO1, Similarity: 0.17
# SMILES: Cc(cc1)cc(C)c1N(CC(NCCc1ccccc1)=O)C(CCC(Nc1ncccc1)=O)=O, Similarity: 0.17
# SMILES: CCN(CC)C(c(sc1nc(N2CCOCC2)c(COC(C)(C)C2)c2c11)c1N)=O, Similarity: 0.17
# SMILES: CC(c(n1C)nnc1SCC(Nc1nc(C)c(C)s1)=O)NC(c1ccccc1)=O, Similarity: 0.17
# SMILES: CCOC(c1c(-c2ccccc2)nc(NC(CSc2nc(cccc3)c3o2)=O)s1)=O, Similarity: 0.17
# SMILES: CCc1nnc(NC(CSc(sc(C(O)=C2)c3NC2=O)c3C#N)=O)s1, Similarity: 0.17
# SMILES: Cc1cc(N(CC(NCCc2ccccc2)=O)C(CCC(Nc2ncccc2)=O)=O)c(C)cc1, Similarity: 0.17
# SMILES: Cc1c(C(N(C(C(NCC2OCCC2)=O)c2ccccc2)c2cc(C)c(C)cc2)=O)sc(C)n1, Similarity: 0.17
# SMILES: N#Cc1c(NC(CSc2nnc(COc(cc3)ccc3Cl)o2)=O)sc2c1CCCC2, Similarity: 0.17
# SMILES: Cc1c(C)sc(N=C(N2CCOC)SCC(Nc(cc(cc3)Cl)c3OC)=O)c1C2=O, Similarity: 0.17
# SMILES: COc(cc1)cc2c1nc(NC(CSc1ncccc1-c1nc(cccc3)c3[nH]1)=O)s2, Similarity: 0.17
# SMILES: CCOc(cc1)ccc1N1C(SCC(Nc2c(C(N)=O)c(CCC3)c3s2)=O)=Nc(cccc2)c2C1=O, Similarity: 0.17
# SMILES: O=C(Cc1nnc(NC(c2ccccc2)=O)s1)N/N=C/c1ccco1, Similarity: 0.17
# SMILES: COc1cccc(OC(C2=Cc(cc(cc3)Br)c3OC2=O)=O)c1, Similarity: 0.17
# SMILES: Cc1cccc(NC(NC(c(cc2)cc(OC)c2OC)=O)=S)n1, Similarity: 0.17
# SMILES: Cc1c(C(N(C(C(NCC2OCCC2)=O)c2ccccc2)c2c(C)ccc(C)c2)=O)sc(C)n1, Similarity: 0.17
# SMILES: Cc(cc1)cc(C)c1N(CC(NCc1ccccc1)=O)C(CCC(Nc1nccs1)=O)=O, Similarity: 0.17
# SMILES: Cc1cc(N(CC(NCc2ccccc2)=O)C(CCC(Nc2nccs2)=O)=O)c(C)cc1, Similarity: 0.17
# ...
# SMILES: CCC1N(CC(N(CC2)CCC2(c2cc(C)ccc2)O)=O)CCCC1, Similarity: 0.10
# SMILES: Cc1cc(NC(C(C(c2nnnn2Cc2ccccc2)N2CCOCC2)=C2)=O)c2c(C)c1, Similarity: 0.10
# SMILES: CC(C)CCNC(CN(C(Cn1nnc(-c(cc2)ccc2F)n1)=O)c(cccc1)c1OC)=O, Similarity: 0.10
# SMILES: COc1c(C(c2nnnn2C2CCCCC2)N(CC2)CCN2C(c2ccco2)=O)cccc1, Similarity: 0.10
# SMILES: CCN(CC)CCCN(CC1=Cc(cc2OCCOc2c2)c2NC1=O)C(Nc(cc1)ccc1F)=O, Similarity: 0.10
# SMILES: COc(cccc1)c1N(C(C(NC1CCCCC1)=O)c(cccc1)c1F)C(Cc1cccs1)=O, Similarity: 0.10
# SMILES: CC(C)(C)n1nnnc1C(C1=Cc(c(C)ccc2C)c2NC1=O)N1CCN(Cc2ccccc2)CC1, Similarity: 0.10
# SMILES: O=C(C(c(cc1)ccc1F)N(C(c1cccs1)=O)c(cc1)cc2c1OCO2)NC1CCCCC1, Similarity: 0.10
# SMILES: CCC(C)(C)NC(C(c(cc1)ccc1F)N(CCc1c(C)cccc1)C(c1nccnc1)=O)=O, Similarity: 0.10
# SMILES: CCc(cc1)ccc1OCC(NC1=CC2NN(c3cc(Cl)c(C)cc3)N=C2C=C1)=O, Similarity: 0.10
# SMILES: CC1C(N(C(C(NC2CCCCC2)=O)c2cnccc2)C(c2ccco2)=O)=CCCC1, Similarity: 0.10
# SMILES: O=C(CN(CC1)CCC1n1nnc2c1ccc(C(F)(F)F)c2)Nc(cc1)cc2c1OCCO2, Similarity: 0.10
# SMILES: O=C(c1ccco1)N(CC1)CCN1C(c1cccs1)c1nnnn1Cc(cc1)ccc1F, Similarity: 0.10
# SMILES: CCOc(cc1)cc(C=C2CN(Cc3cnccc3)S(c(cc3)ccc3OC)(=O)=O)c1NC2=O, Similarity: 0.10
# SMILES: CCc1c(C)sc(N=CN2C(CC3)CCN3C(c3cc(C(C)(C)C)nn3C)=O)c1C2=O, Similarity: 0.10
# SMILES: CCOc1ccc(C(C(NC(C)(C)C)=O)N(C(C)c2ccccc2)C(Cn2nnc3c2cccc3)=O)cc1, Similarity: 0.10
# SMILES: CCCc1nc(NCc(cc2)cc3c2OCO3)c2nnn(Cc(cccc3)c3Cl)c2n1, Similarity: 0.10
# SMILES: O=C(C(c(cc1)ccc1F)N(CC1OCCC1)C(c1ccc(-c2ccccc2)[nH]1)=O)NCC1OCCC1, Similarity: 0.10
# SMILES: CCC(c1nnnn1CC1OCCC1)N(Cc1ccccc1)CC1=Cc(cc(C)cc2)c2NC1=O, Similarity: 0.10
# SMILES: CCOc(cc1)cc(C=C2CN(CCCN3CCOCC3)C(Nc3cccc(Cl)c3)=O)c1NC2=O, Similarity: 0.10
# SMILES: COc(cc1)ccc1-c1nn(CC(N(Cc2cccs2)C(C(NC2CCCC2)=O)c(cc2)ccc2F)=O)nn1, Similarity: 0.10
# SMILES: O=C1Oc(cccc2)c2C(Sc2ccccc2)=C1Sc1ccccc1, Similarity: 0.10
# SMILES: CCc(cc(C(C)(C)CCC1(C)C)c1c1)c1C(C)=O, Similarity: 0.10
# SMILES: CC(CC1(C)C)c(cccc2)c2N1C(c(cccc1)c1F)=O, Similarity: 0.10
# SMILES: O=C(c1ccccc1)c(ccc1c2c(C=C3)c(-c4ccccc4)o1)c2C3=O, Similarity: 0.10
# SMILES: CCN(CC)CCCOC(c(ccc(OC)c1)c1O)=O, Similarity: 0.10
# SMILES: Cc(cc1)ccc1S(N(CC1)CCN1C(c1ccco1)=O)(=O)=O, Similarity: 0.10
# SMILES: CCOC(c1c(C)n(CCO)c(cc2)c1cc2O)=O, Similarity: 0.10
# SMILES: CCSC(N1C)=Nc(sc2c3CCCC2)c3C1=O, Similarity: 0.10
# SMILES: C(c1c[nH]c2c1cccc2)N1CCN(Cc2cccnc2)CC1, Similarity: 0.10
# SMILES: CC(C)c1c(NC2CCCC2)n(cc(cc2)Br)c2n1, Similarity: 0.10
# SMILES: CN(c1c(C(N2)=O)n(CC(CS3)O)c3n1)C2=O, Similarity: 0.10
# SMILES: CCOc(cc1O)cc(OC(c2ccccc2)=C2)c1C2=O, Similarity: 0.10
# SMILES: CCN(CC)C(C1CCN(CC(C)c2ccccc2)CC1)=O, Similarity: 0.10
# SMILES: O=S(c1c(N2CCOCC2)oc(-c2ccccc2)n1)(c1ccccc1)=O, Similarity: 0.10
# SMILES: C#CCOc(cc1)cc(O2)c1C(CCCC1)=C1C2=O, Similarity: 0.10
# SMILES: Cc1cc(NC(NC2CC(CC3)N(C4CC4)C3C2)=S)c(C)cc1, Similarity: 0.10
# SMILES: O=C(CNC1CCCC1)Nc(cc1)ccc1C(N1CCCCCC1)=O, Similarity: 0.10
# SMILES: CCOC(c(cc1)ccc1NC(C(CC(C)=C(C)C1)C1C(O)=O)=O)=O, Similarity: 0.10
# SMILES: O=C(c(cc1)cc2c1OCO2)OCC1CCNCC1, Similarity: 0.10
# SMILES: CC(C)[C@@H](CN(C(C=C1)=O)N=C1c1cccs1)N, Similarity: 0.10
# SMILES: CN(C)CCOC(C(C1CCCC1)(c1ccccc1)O)=O, Similarity: 0.10
# SMILES: CC(Cn1c(N(C)C)nc(N(C)C(N2)=O)c1C2=O)O, Similarity: 0.10
# SMILES: Cc(cc1)nn1S(c(cc1)cc(C=C2)c1OC2=O)(=O)=O, Similarity: 0.10
# SMILES: Cc(cc1)ccc1C(C1CCN(CC(NC2CCCC2)=O)CC1)=O, Similarity: 0.10
# SMILES: CN(c1c(C(N2)=O)n(CCO)c(NCCCO)n1)C2=O, Similarity: 0.10
# SMILES: CC(C)NC(C(CCC1)N1C(Nc1cc(C)cc(C)c1)=O)=O, Similarity: 0.10
# SMILES: COc(c(OC)c1)cc2c1N=C(c(cc1)cc(Cl)c1Cl)OC2=O, Similarity: 0.10
# SMILES: COCCNC(c1ccc(CN2CCOCC2)cc1)=O, Similarity: 0.10
# SMILES: CC(O/N=C(/c1nonc1N)\N1CCOCC1)=O, Similarity: 0.10
# SMILES: OC(CN1CCNCC1)COc1cccc2ccccc12, Similarity: 0.10
# SMILES: CC(C(ON=C1C)=O)=C1c(cc1)cc(C([O-])=O)c1Cl, Similarity: 0.10
# SMILES: CCc(cccc1)c1N(CC(NCc1ccco1)=O)S(c1ccc(C)cc1)(=O)=O, Similarity: 0.10
# SMILES: CCOc(ccc(CN(CC1)CCN1S(c1cc2ccccc2cc1)(=O)=O)c1)c1OC, Similarity: 0.10
# SMILES: Fc(cc1)ccc1Oc1nc(N2CCCC2)nc2c1CN(Cc1ccccc1)CC2, Similarity: 0.10
# SMILES: Fc(cc1)ccc1-c1c(NCc(cc2)cc3c2OCO3)n(cccc2)c2n1, Similarity: 0.10
# SMILES: Cc(cc1)ccc1C(CSc1nnc(-c2ccco2)n1CCOC)=O, Similarity: 0.10
# SMILES: CCOC(c(cc1)ccc1NC(CSc1nnc(C2CC2)n1C)=O)=O, Similarity: 0.10
# SMILES: CCOC(CSc1nnc(-c(cc2)ccc2O)n1Cc1ccco1)=O, Similarity: 0.10
# SMILES: CC(C)CCN(C(C(NC(C)(C)C)=O)c1ccc(C)cc1)C(c1csnn1)=O, Similarity: 0.10
# SMILES: Cc1cccc2nc(-c(cc3)ccc3Cl)c(NCC3OCCC3)n12, Similarity: 0.10
# SMILES: CC(C)OC(CSc1nnc(-c2ccccc2)n1Cc1ccco1)=O, Similarity: 0.10
# SMILES: CCOc(cc1)ccc1C(C(C(C1)c2ccccc2)c(cc(c(OC)c2)OC)c2C1=O)=O, Similarity: 0.10
# SMILES: CN(CCc1ccccc1)c(nc1)nc(-c2nccn2C)c1-c(cc1)ccc1F, Similarity: 0.10
# SMILES: CCN(CC)c(cc1)cc(OC2=O)c1C(C)=C2/N=C/c1cccc2ccccc12, Similarity: 0.10
# SMILES: Cc1c(C)sc(N=C(C)N2/N=C/c3cc(Cl)cc(Cl)c3OC)c1C2=O, Similarity: 0.10
# SMILES: CC(CC1N(C(c(cc2)cc3c2OCO3)=O)c2ccccc2)Nc2c1cccc2, Similarity: 0.10
# SMILES: CCOC(C(C1C(N2c(cc(cc3)OC)c3OC)=O)=NNC1C2=O)=O, Similarity: 0.10
# SMILES: CCn1c(SCC(Nc(cc2)ccc2C(C)=O)=O)nnc1C1CCCCC1, Similarity: 0.10
# SMILES: Cc(cc1)cc(C=C2CN(Cc3ccccc3)S(c(cccc3)c3Cl)(=O)=O)c1NC2=O, Similarity: 0.10
# SMILES: CCCCNC(N(CCN(C)C)CC1=Cc(c(C)ccc2C)c2NC1=O)=S, Similarity: 0.10
# SMILES: O=C(CSc1nnc(-c2ccco2)n1Cc1ccco1)c(cccc1)c1F, Similarity: 0.10
# SMILES: CCOCCCNC(C(CC1)CCN1c1nc(OCC)cc(C)n1)=O, Similarity: 0.10
# SMILES: CC1Oc(cccc2)c2N(CC(N(Cc2ccccc2)Cc(cccc2)c2F)=O)C1=O, Similarity: 0.10
# SMILES: COc(cc1)ccc1C(C1CCN(Cc2nnnn2C2CCCCC2)CC1)=O, Similarity: 0.10
# SMILES: CCC1Oc2nc3c(Cc4ccccc4)cccc3cc2CN(Cc2ccccc2)C1, Similarity: 0.10
# SMILES: CN(C)c1nc2ccccc2cc1CN(Cc1ccncc1)Cc(ccc(OC)c1)c1OC, Similarity: 0.10
# SMILES: O=C(C(C1)C2(CCCCC2)OC1=O)NCC1OCCc2c1cccc2, Similarity: 0.10
# SMILES: COc1c(CCN(CCOc2nc3c(cc4)OC)Cc2cc3c4OC)cccc1, Similarity: 0.10
# SMILES: Cc(cc1)ccc1C(NC1CC(CC2)N(Cc3nnnn3C3CCCC3)C2C1)=O, Similarity: 0.10
# SMILES: Cc(c(C=C1CNC2CCCC2)c2NC1=O)nn2-c(cc1)ccc1Cl, Similarity: 0.10
# SMILES: CCN(C(CN(c1c(C(N2C)=O)scc1)C2=O)=O)c1cc(C)ccc1, Similarity: 0.10
# SMILES: CC(C)Oc1c(CN(C(C2NC(C)=O)=O)c3c2cccc3C)cccc1, Similarity: 0.10
# SMILES: CC(C)N(C(C)C)C(CN(CC1)CCC1N(C(C1CC1)=Nc1c2c(C)c(C)s1)C2=O)=O, Similarity: 0.10
# SMILES: CS(N(CCCC(Nc(cc1)cc2c1OCCO2)=O)c(cc1)ccc1Cl)(=O)=O, Similarity: 0.10
# SMILES: CS(N(CCCC(Nc(cc1)cc2c1OCCO2)=O)c(cc1)ccc1F)(=O)=O, Similarity: 0.10
# SMILES: O=C(CSc1nnnn1C1CCCCC1)NCc1ccco1, Similarity: 0.10
# SMILES: CSc(cc1)ccc1S(N(CC1)CCC1C(NCC1OCCC1)=O)(=O)=O, Similarity: 0.10
# SMILES: CC(C)(C)NC(CSc1nnc(-c2ccncc2)n1CCCOC)=O, Similarity: 0.10
# SMILES: Cc1cccn2c1nc(-c(cc1)ccc1F)c2NCC1OCCC1, Similarity: 0.10
# SMILES: COc(c(OC)c1)cc(C(O)=C2C(NCCN3CCOCC3)=O)c1NC2=O, Similarity: 0.10
# SMILES: Cc1nnc(Sc2nc(N(C)C(N(C)C3=O)=O)c3n2Cc(cc2)ccc2Cl)s1, Similarity: 0.10
# SMILES: CCOC(C(C1C(N2c(ccc(OC)c3)c3OC)=O)=NNC1C2=O)=O, Similarity: 0.10
# SMILES: CC(C)(OCC1OC(C2NC(C)=O)Oc(cccc3)c3OC)OC1C2O, Similarity: 0.10
# SMILES: CCOC(c1c(NC(CCN2CCOCC2)=O)sc2c1CCCC2)=O, Similarity: 0.10
# SMILES: Nc1nc(CSc2nnc(-c3ccncc3)o2)nc(Nc(cc2)ccc2F)n1, Similarity: 0.10
# SMILES: FC(c1cc(CN(CC2OCCC2)Cc2ncccc2)ccc1)(F)F, Similarity: 0.10
# SMILES: CCn1c(SC)nnc1C(CC1)CCN1C(C(c1ccccc1)OC)=O, Similarity: 0.10
# SMILES: O=C(Cn1nnc2c1cccc2)N(C(C(NCc1ccco1)=O)c1cnccc1)c1ccccc1, Similarity: 0.10
# SMILES: CC(C)(C)n1nnnc1C(C1=Cc(ccc(C)c2)c2NC1=O)N1CCN(Cc2ccccc2)CC1, Similarity: 0.10
# SMILES: COc(cc1)ccc1-n1c(SCC(NCc2ccco2)=O)nnc1-c1cnccc1, Similarity: 0.10
# SMILES: CCc1ccc(C(C(NC(C)(C)C)=O)N(Cc2ccco2)C(Cn2nnc3c2cccc3)=O)cc1, Similarity: 0.10
# SMILES: CC(C)(C)NC(C(c1cccs1)N(Cc(cc1)ccc1F)C(Cn1nnc(-c(cc2)ccc2F)n1)=O)=O, Similarity: 0.10
# SMILES: CCOC(c(cc1)ccc1N(C(C(NC1CCCC1)=O)c1cccs1)C(c1ccco1)=O)=O, Similarity: 0.10
# SMILES: Cc(cc1)cc(C)c1-n1c(SCC(NCc2ccco2)=O)nnc1-c1cnccc1, Similarity: 0.10
# SMILES: O=C(C(c(cc1)ccc1F)N(C(C1Oc(cccc2)c2OC1)=O)c(cc1)cc2c1OCO2)NC1CCCCC1, Similarity: 0.10
# SMILES: CCc(cc1)ccc1N(C(C(NCCC(C)C)=O)c1ccc(C)cc1)C(Cn1nnc2c1cccc2)=O, Similarity: 0.10
# SMILES: Cc(cc1)cc(N2)c1C=C(CN(CCN1CCOCC1)C(Nc(cc1)ccc1F)=O)C2=O, Similarity: 0.10
# SMILES: CCc1ccc(C(C(NC(C)(C)C)=O)N(C(Cn2nnc3c2cccc3)=O)c(cccc2)c2C(C)=O)cc1, Similarity: 0.10
# SMILES: CCc1ccc(C(C(NC(C)(C)C)=O)N(C(Cn2nnc3c2cccc3)=O)c(cc2)ccc2C(C)=O)cc1, Similarity: 0.10
# SMILES: Cc(cccc1cc2CN3CC4OCCC4)c1nc2S/C3=N/c1cc(OC)ccc1, Similarity: 0.10
# SMILES: CCc(cc1)ccc1N(C(C(NC1CCCCC1)=O)c1cnccc1)C(c1csnn1)=O, Similarity: 0.10
# SMILES: CCCCC(C(C1C(N2c(cc3)ccc3OCC)=O)C2=O)(C(OCC)=O)NC1c1cccs1, Similarity: 0.10
# SMILES: CC(CCCC1)C1NC(C(C1C(N(C2C(NC(C)(C)C)=O)c3ccccc3)=O)C3(C)OC12C=C3)=O, Similarity: 0.10
# SMILES: Cc1nc(cccc2)c2n1CCC(N(CC1)CCC1c1ccnc2nc(C(F)(F)F)nn12)=O, Similarity: 0.10
# SMILES: CCn1c(SCC)nnc1C1CN(CC(Nc(cc2)cc3c2OCO3)=O)CCC1, Similarity: 0.10
# SMILES: CCC(C(C1C(N2c3cc(C(C)=O)ccc3)=O)C2=O)(C(OCC)=O)NC1c(cc1)cc(OC)c1OC, Similarity: 0.10
# SMILES: CC(C)NC(C(c(cc1)ccc1OC)N(C1CCCC1)C(c(cc1)cc(N2)c1OCC2=O)=O)=O, Similarity: 0.10
# SMILES: Cc(cc1)cc(N2)c1C=C(C(c(cc1OC)c(CC3)cc1OC)N3C(c1ccco1)=O)C2=O, Similarity: 0.10
# SMILES: Cc(cc1)ccc1NC(N(CCN1CCOCC1)CC1=Cc(cc2OCOc2c2)c2NC1=O)=O, Similarity: 0.10
# SMILES: Cn(c(C(N(CC1OCCC1)Cc(ccc(OC)c1)c1OC)=O)c1)c2c1scc2, Similarity: 0.10
# SMILES: CC(C1)(C(N(CC(NC2CCCC2)=O)c2c(C)cccc2)=O)N(C=CC(C)=C2)C2=NC1=O, Similarity: 0.10
# SMILES: O=C(c1ccccc1)N(CC1N2CCc3c1cccc3)CC2=O, Similarity: 0.10
# SMILES: Cc(cc1)cc(C=C2c3c(NCc(cc4)cc5c4OCO5)n(cccc4)c4n3)c1NC2=O, Similarity: 0.10
# SMILES: CCCCNC(Cn1nc(C(F)(F)F)c(Br)c1C)=O, Similarity: 0.10
# SMILES: Nc1c(c(-c2ccco2)c(-c2cocc2)o2)c2ncn1, Similarity: 0.10
# SMILES: CSc1ccc(C(C2)c(c3ccccc3cc3)c3NC2=O)cc1, Similarity: 0.10
# SMILES: CCn1c(SCC(O)=O)nc(N(C)C(N2)=O)c1C2=O, Similarity: 0.10
# SMILES: c1ccc(C(c2ccccc2)Sc2nc(cccc3)c3o2)cc1, Similarity: 0.10
# SMILES: CCc(cc1)cc(C=C2C(c3nnnn3CCc3ccccc3)N3CCC(C)CC3)c1NC2=O, Similarity: 0.10
# SMILES: COC(c(cc1)ccc1NS(c(cc1)cc2c1OCCO2)(=O)=O)=O, Similarity: 0.10
# SMILES: Cc1ccc(C(C(NCc2ccco2)=O)N(Cc2cccs2)C(c(cc2)cc3c2OCCO3)=O)cc1, Similarity: 0.10
# SMILES: CC(C)(C)NC(C1CCN(Cc(cc2)ccc2OC)CC1)=O, Similarity: 0.10
# SMILES: Cc1ccc(Cn2c(SCC(CO)O)nc(N(C)C(N3)=O)c2C3=O)cc1, Similarity: 0.10
# SMILES: CC(C(NC1CCCCC1)=O)N(C(Cn1nnc(-c(cc2)ccc2OC)n1)=O)c1ccc(C2CCCCC2)cc1, Similarity: 0.10
# SMILES: O=C1Nc(cc2OCCOc2c2)c2C=C1CN(Cc1nnnn1Cc1ccccc1)C1CCCC1, Similarity: 0.10
# SMILES: O=C(CC1c2c(C(F)(F)F)cccc2)Nc2c1c1ccccc1cc2, Similarity: 0.10
# SMILES: COc(ccc(C(c1nnnn1C1CCCC1)N(CC1)CCN1C(c1ccco1)=O)c1)c1OC, Similarity: 0.10
# SMILES: Cc1cccc(C=C2C(c3nnnn3C3CCCCC3)N(CC3)c4c3cccc4)c1NC2=O, Similarity: 0.10
# SMILES: O=C1Oc(cccc2)c2C(Nc2ccccc2)=C1CN1CCCC1, Similarity: 0.10
# SMILES: CCC(c1nnnn1C1CCCC1)N(Cc1ccccc1)CC1=Cc(c(C)ccc2C)c2NC1=O, Similarity: 0.10
# SMILES: Cc(occ1)c1-c(n1C)nnc1SCC(Nc(cc1)ccc1C(OC)=O)=O, Similarity: 0.10
# SMILES: CN(C)C(CSc1nnc(-c2cnccc2)n1-c(cc1)ccc1OC)=O, Similarity: 0.10
# SMILES: FC(c1cc(/N=C(/c2ccccc2)\N2CCOCC2)ccc1)(F)F, Similarity: 0.10
# SMILES: Cc(cc1)ccc1NC(NC(CC1)CCN1C(N1CCOCC1)=O)=O, Similarity: 0.10
# SMILES: COc(c(O)ccc1)c1-c1nn(CCC(OCC(c2ccccc2)=O)=O)nn1, Similarity: 0.10
# SMILES: CCOC(c(cc1)ccc1NC(C(C1CC2CC1)C2C(O)=O)=O)=O, Similarity: 0.10
# SMILES: CC(C(C(C12)C(N3c4ncccc4)=O)C3=O)(c3c2cccc3)c2c1cccc2, Similarity: 0.10
# SMILES: CC(c(cc1)ccc1Br)(N1)SCC1=O, Similarity: 0.10
# SMILES: CC(C)C1Oc2cc(OC(C=C3)=O)c3cc2/C1=N\O, Similarity: 0.10
# SMILES: CCCCn1c(ccc(O)c2)c2c(C(OCC)=O)c1C, Similarity: 0.10
# SMILES: COc1c(C(C2)c(ccc3ccccc33)c3NC2=O)cccc1, Similarity: 0.10
# SMILES: COc1c2OCOc2cc(CNc(cc2)ccc2Br)c1, Similarity: 0.10
# SMILES: Cc(cc1)ccc1-c1nnc(C2=Cc(cc(cc3)Cl)c3OC2=O)o1, Similarity: 0.10
# SMILES: Cc(cc1)ccc1NCc(n1C)nnc1SCc1ccccc1, Similarity: 0.10
# SMILES: Cc(cc1)cc(C=C2CN(CC3OCCC3)C(NCCCOC)=S)c1NC2=O, Similarity: 0.10
# SMILES: Cc(cc1)ccc1-c1noc(CC2(CN(Cc(cc3)ccc3OC)CCC2)C(N(C)C)=O)c1, Similarity: 0.10
# SMILES: Cc(cc1)ccc1-n1nnnc1SCC(N(CCC1)c2c1cccc2)=O, Similarity: 0.10
# SMILES: Cc1cc(NS(c(cc2)ccc2Nc2nc(-c(cc3)ccc3Cl)cs2)(=O)=O)no1, Similarity: 0.10
# SMILES: COc(cccc1)c1N(CC1)CCN1C(Nc(cc1)ccc1F)=S, Similarity: 0.10
# SMILES: CCCCOc(cc1)ccc1-c1nc(-c(cccc2)c2Cl)no1, Similarity: 0.10
# SMILES: NC(N/N=C/c1ccc(-c2cccc(Cl)c2)o1)=S, Similarity: 0.10
# SMILES: CC(CN1CCCCC1)OC(c(cc1)cc(OC)c1OC)=O, Similarity: 0.10
# SMILES: COc(cc1)cc(C(CSc2nnc(COc(cc3)ccc3Cl)o2)=O)c1OC, Similarity: 0.10
# SMILES: Oc(cc1)ccc1NC(Nc(cc1)ccc1O)=S, Similarity: 0.10
# SMILES: CC(C)(C)NC(CN(c(cc1)c(C)cc1Cl)S(C)(=O)=O)=O, Similarity: 0.10
# SMILES: CC(C)CCNC(C(c(cc1)ccc1F)N(Cc(cccc1)c1Cl)C(Cn1nnc2c1cccc2)=O)=O, Similarity: 0.10
# SMILES: Cc(cccc1)c1/N=C(\c1cccs1)/NC1CCCCC1, Similarity: 0.10
# SMILES: CCOC(C(C)(C)Sc1nnc(-c2ccc(C)cc2)n1C)=O, Similarity: 0.10
# SMILES: CCOC(Cn1nnnc1CN(Cc(cc1)ccc1F)CC1=Cc(cc(C)c(C)c2)c2NC1=O)=O, Similarity: 0.10
# SMILES: COc(cc1)cc(CNCCc2cccc(F)c2)c1OC, Similarity: 0.10
# SMILES: CCOC(c(cc1)ccc1NC(N1CCOCC1)=S)=O, Similarity: 0.10
# SMILES: O=C(c(cc1)ccc1F)N1CCN(Cc2c(C(F)(F)F)cccc2)CC1, Similarity: 0.10
# SMILES: Cc(cc1)cc(C)c1NC(NC1CC(CC2)N(Cc3ccco3)C2C1)=S, Similarity: 0.10
# SMILES: Cc(cc1C)cc(C=C2CN(CCN3CCOCC3)C(Nc(cc3)ccc3F)=O)c1NC2=O, Similarity: 0.10
# SMILES: Cc1ccc(C(C(NC2CCCC2)=O)OC(C2=Cc(cccc3)c3OC2)=O)cc1, Similarity: 0.10
# SMILES: CC(C(NC(C)(C)C)=O)OC(C(C1C(N(C2)c3c(C)cc(C)cc3)=O)C3OC12C=C3)=O, Similarity: 0.10
# SMILES: OC1(CC(CC2)N(CC(Nc(cc3)cc4c3OCO4)=O)C2C1)c(cc1)ccc1F, Similarity: 0.10
# SMILES: O=C(Cn1nnc(-c2ccc(CN3CCCCC3)cc2)n1)N(CCC1)c2c1cccc2, Similarity: 0.10
# SMILES: CCOc1ccc2nc3OC(C)CN(Cc4ccccc4)Cc3cc2c1, Similarity: 0.10
# SMILES: O=C(C(c1ccco1)N(C(c1cccs1)=O)c(cc1)ccc1F)NCc1ccco1, Similarity: 0.10
# SMILES: COc1c(C(CC2N(Cc3ccccc3)C3CC2)C3OC(c2ccccc2)=O)cccc1, Similarity: 0.10
# SMILES: CCC(c(cc1)ccc1F)n1nnc(C(NCCN2CCN(CC)CC2)=O)c1, Similarity: 0.10
# SMILES: O=C(CN(CC1)CCC1NC(Nc(cc1)ccc1F)=O)c(cc1)ccc1F, Similarity: 0.10
# SMILES: Oc1c(CN(CC2)C(C3CCCC3)=O)c2nc2cc(C(CCC3)CN3C(C3CCCC3)=O)nn12, Similarity: 0.10
# SMILES: CC(c(cc1)ccc1NC(N(CC1)CCN1C(C(Cc1c(C)ccc(C)c1)NC(C)=O)=O)=O)=O, Similarity: 0.10
# SMILES: Cc1cccc(-c2noc(CC(CCC3)(CN3C(CCC3CCCC3)=O)C(O)=O)c2)c1, Similarity: 0.10
# SMILES: CC(C(Nc1c2c(C)nn1-c1ccccc1)=O)SC2c(cc1)cc(OC)c1OCC#C, Similarity: 0.10
# SMILES: CCN1CCN(Cc2nc(Nc3ccc(C)cc3)nc(N)n2)CC1, Similarity: 0.10
# SMILES: O=C(C1CC1)N(CCC1)CC1c1nc(N2CCCCC2)ncc1-c1cnccc1, Similarity: 0.10
# SMILES: CC(C(Nc1c2c(C)n[nH]1)=O)SC2c1c(C)cccc1, Similarity: 0.10
# SMILES: CC(C(Nc1c2c(C)nn1-c1ccccc1)=O)SC2c(cc(c(OC)c1)OC)c1OC, Similarity: 0.10
# SMILES: Cc(cccc1)c1OCc1nc(-c2cccs2)no1, Similarity: 0.10
# SMILES: COc1c(C(CC2)(CCN2S(c(s2)ccc2Cl)(=O)=O)O)cnc(OC)n1, Similarity: 0.10
# SMILES: COc(cc(CN(CC1)CCN1c1c(C(c2nccs2)O)cccc1)cc1)c1OCC#C, Similarity: 0.10
# SMILES: CC(C)N1CC(CN(C)C(CN(C[C@@H]2c3csnn3)C[C@@H]2c2c(C)cccc2)=O)CCC1, Similarity: 0.10
# SMILES: CC(Nc1ccc(CN(CC2)CCC2C(C2)N(C)CC2C(Nc(cc2)ccc2F)=O)cc1)=O, Similarity: 0.10
# SMILES: CCCNc1nc(N(C)C(NC2=O)=O)c2n1CCO, Similarity: 0.10
# SMILES: CC(C1)N(C(CSc2nnc(C3CCCCC3)n2C)=O)c2c1cccc2, Similarity: 0.10
# SMILES: C1OC(c2cc3cccnc3cc2)Nc2c1cccc2, Similarity: 0.10
# SMILES: c1cocc1-c1c(-c2cocc2)nnc2nc(-c(cc3)ccc3-c3ccccc3)cn12, Similarity: 0.10
# SMILES: Cc1ccc(CN(C(c2c(N3C)nc(NC)n2C)=O)C3=O)cc1, Similarity: 0.10
# SMILES: O=C(CSc(cc1)nnc1-c(cc1)ccc1F)NCc(cc1)ccc1F, Similarity: 0.10
# SMILES: CN(C)c(cc1)ccc1C(NC1(CCCC1)N(CC1)C1=O)=O, Similarity: 0.10
# SMILES: CN(c1c(C(N2)=O)n(CCOC)c(NCCOC)n1)C2=O, Similarity: 0.10
# SMILES: CCCC(C(C1C(N2C)=O)C2=O)(C(OCC)=O)NC1c1ccco1, Similarity: 0.10
# SMILES: Cc1cc(-c2nc(-c3ccncc3)no2)cc(C)c1, Similarity: 0.10
# SMILES: CC(CC1)CCN1S(c(cc1)ccc1OCC(OC)=O)(=O)=O, Similarity: 0.10
# SMILES: CCC(C(C(C12)C(N3Cc4ccccc4)=O)C3=O)(c3c2cccc3)c2c1cccc2, Similarity: 0.10
# SMILES: CCOC(c(cc1)ccc1Oc1nc(OC)nc(N(C)C)n1)=O, Similarity: 0.10
# SMILES: Cc(occ1)c1-c1nnc2sc(-c(cc3)ccc3Cl)nn12, Similarity: 0.10
# SMILES: COC(c1ccc(COc2ccc(/C=N\O)cc2)o1)=O, Similarity: 0.10
# SMILES: COCCNC(CN(CC1)CCC1NC(Nc1ccc(C(F)(F)F)cc1)=O)=O, Similarity: 0.10
# SMILES: CCc(c(C)nc1nnc(NC(C(F)(F)F)=O)n11)c1O, Similarity: 0.10
# SMILES: NCC(c(cccc1)c1Cl)N1CCCCCC1, Similarity: 0.10
# SMILES: CN(C(c1ccccc1)N1C)C(c2ccccc2)SC1=S, Similarity: 0.10
# SMILES: CC(NC(Cc1c(C)cccc1)C(NC(CC1)CCN1C(c1ccc(C)cc1)=O)=O)=O, Similarity: 0.10
# SMILES: C[C@@H]1N(Cc2ccccc2)CCN(Cc2cccc(OC)c2)C1, Similarity: 0.10
# Results saved to similar_molecules.csv
